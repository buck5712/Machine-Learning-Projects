# %%
m = 3
s = 5

# %% [markdown]
# # 1. Random Data Generator

# %%
import random
import math
import numpy as np

def gaussian_data_generator(m, s):
    U=random.random()
    V=random.random()
    z=math.sqrt(-2*math.log(U))*math.cos(2*math.pi*V)
    sample=z * (s**0.5) + m
    return sample
# Out:
# C:\Users\Buck\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Buck\anaconda3\lib\site-packages\numpy\.libs\libopenblas.4SP5SUA7CBGXUEOC35YP2ASOICYYEQZZ.gfortran-win_amd64.dll
# C:\Users\Buck\anaconda3\lib\site-packages\numpy\.libs\libopenblas.JPIJNSWNNAN3CE6LLI5FWSPHUT2VXMTH.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
for i in range(10):
    res = gaussian_data_generator(m, s)
    print(res)
# Out:
# 4.290708501875573
# 2.792847180139669
# -2.7473871021050265
# 4.078645280400362
# 2.025594295936123
# 5.920027419494191
# 0.1177966439419551
# 3.141722690815472
# 1.1955045920546221
# 6.700750612875201

# %% [markdown]
# # 2. Sequential Estimator

# %%
m_estimate = 0
s_estimate = 0
sum = 0
sumsq = 0
n = 0
print('Data point source function: N({},{})'.format(m,s))
while abs(m_estimate - m) > 0.1 or abs(s_estimate - s) > 0.1:
    point = gaussian_data_generator(m, s)
    n += 1
    sum += point
    sumsq += point**2
    m_estimate = sum / n
    if n > 1:
        s_estimate = (sumsq - sum**2 / n) / (n-1)
    print('Add data point: {}'.format(point))
    print('Mean={}  Variance={}'.format(m_estimate,s_estimate))
    print()
# Out:
# Data point source function: N(3,5)
# Add data point: -0.09032820669087505
# Mean=-0.09032820669087505  Variance=0
#
# Add data point: 4.1585484910675845
# Mean=2.0341101421883545  Variance=9.02647659637742
#
# Add data point: 3.4567391903016738
# Mean=2.5083198248927943  Variance=5.187862767700645
#
# Add data point: 4.8074450120495085
# Mean=3.083101121681973  Variance=4.780069335021696
#
# Add data point: 6.076626845326789
# Mean=3.6818062664109363  Variance=5.377291252890917
#
# Add data point: 2.4093404754692243
# Mean=3.4697286345873177  Variance=4.5716945338322175
#
# Add data point: 2.3684358970445523
# Mean=3.312401100652637  Variance=3.9830091153979574
#
# Add data point: 0.12234061419572528
# Mean=2.913643539845523  Variance=4.686068551604963
#
# Add data point: 5.257409678751992
# Mean=3.1740619997240196  Variance=4.710669950863737
#
# Add data point: 0.627116794852256
# Mean=2.9193674792368434  Variance=4.835955166207471
#
# Add data point: 1.5908274097455002
# Mean=2.798591109283085  Variance=4.512815896518001
#
# Add data point: 1.8103337255255296
# Mean=2.716236327303289  Variance=4.1839476273047325
#
# Add data point: 4.822693018173323
# Mean=2.878271457370215  Variance=4.176605308914809
#
# Add data point: 6.275512847258032
# Mean=3.1209315566479154  Variance=4.6797029104003185
#
# Add data point: 4.408284233929091
# Mean=3.206755068466661  Variance=4.455923544513829
#
# Add data point: 2.273163366461306
# Mean=3.148405587091326  Variance=4.213336566507904
#
# Add data point: 1.564812121196803
# Mean=3.055253030274001  Variance=4.0975188114084435
#
# Add data point: 3.8868826173477458
# Mean=3.1014546740003204  Variance=3.8949109469845484
#
# Add data point: 5.8990595850770475
# Mean=3.2486970377412008  Variance=4.090452965405441
#
# Add data point: 6.616600944981884
# Mean=3.417092233103235  Variance=4.442304803646557
#
# Add data point: 2.73398518799297
# Mean=3.3845633261932226  Variance=4.242410288944195
#
# Add data point: 2.0643759225802043
# Mean=3.324554807847176  Variance=4.119613241405357
#
# Add data point: -2.1509835816431444
# Mean=3.086487921347597  Variance=5.235902470363632
#
# Add data point: 7.0957136110646655
# Mean=3.2535389917524746  Variance=5.677999979831531
#
# Add data point: 1.5532367164222387
# Mean=3.185526900739265  Variance=5.55705776043828
#
# Add data point: 1.0461073294719576
# Mean=3.103241532613599  Variance=5.510818377017733
#
# Add data point: -0.8576591848169572
# Mean=2.956541506042097  Variance=5.879928064549655
#
# Add data point: 3.073969774728333
# Mean=2.9607353727808916  Variance=5.662645429558053
#
# Add data point: 5.821728882202567
# Mean=3.0593903213816387  Variance=5.74265926040719
#
# Add data point: 3.35890687691081
# Mean=3.0693742065659446  Variance=5.547626866190902
#
# Add data point: 7.722767298923242
# Mean=3.2194836611581157  Variance=6.061224269747934
#
# Add data point: 4.600957620875263
# Mean=3.2626547223992763  Variance=5.925340603125698
#
# Add data point: 5.597216984764408
# Mean=3.3333990333800383  Variance=5.9053307079707285
#
# Add data point: 1.778536044566063
# Mean=3.2876677690031566  Variance=5.797487142988955
#
# Add data point: 1.9488342580994011
# Mean=3.2494153829773347  Variance=5.678186391537383
#
# Add data point: 4.991367728307049
# Mean=3.2978029481253825  Variance=5.600241327230752
#
# Add data point: 2.9970851374992775
# Mean=3.2896754397300825  Variance=5.4471231546714876
#
# Add data point: 2.1610735288276266
# Mean=3.2599753894431758  Variance=5.3334231434583375
#
# Add data point: 5.015269360359316
# Mean=3.304982927158975  Variance=5.272071362439331
#
# Add data point: 2.4184005694078516
# Mean=3.282818368215197  Variance=5.156540752380597
#
# Add data point: 2.9039141894459695
# Mean=3.273576802879362  Variance=5.031128901295196
#
# Add data point: 5.02047156000955
# Mean=3.3151695351919854  Variance=4.981076566299636
#
# Add data point: 3.515291376211599
# Mean=3.319823531494767  Variance=4.863410871505478
#
# Add data point: 3.2188818537303634
# Mean=3.317529402454667  Variance=4.75053986633269
#
# Add data point: 0.0026910553389813963
# Mean=3.243866328074318  Variance=4.886754234911179
#
# Add data point: 4.669992074971837
# Mean=3.274869061702525  Variance=4.822373493008988
#
# Add data point: 3.580250742929344
# Mean=3.281366544281819  Variance=4.719523498793036
#
# Add data point: 0.9330809325066265
# Mean=3.2324439273698355  Variance=4.7339923825864965
#
# Add data point: 5.748186967601907
# Mean=3.2837856220684487  Variance=4.764530052394368
#
# Add data point: 2.178257642419635
# Mean=3.2616750624754722  Variance=4.691738587478375
#
# Add data point: 4.199575543448208
# Mean=3.280065267984742  Variance=4.6151519983211395
#
# Add data point: 9.241317878750236
# Mean=3.394704741268694  Variance=5.208053681294207
#
# Add data point: -0.0028525559317591487
# Mean=3.3305998866045345  Variance=5.325698719557971
#
# Add data point: -0.10463593220537737
# Mean=3.2669844084784248  Variance=5.443748007146408
#
# Add data point: 2.2264169435775485
# Mean=3.2480650000256817  Variance=5.362624779757012
#
# Add data point: 2.75272098570275
# Mean=3.2392195711984866  Variance=5.269504041257828
#
# Add data point: 0.8951708616316703
# Mean=3.198095909627139  Variance=5.2718016206457765
#
# Add data point: 6.155247357547568
# Mean=3.2490812794188706  Variance=5.330085333017524
#
# Add data point: 0.08104822775209364
# Mean=3.195385803966891  Variance=5.408296350991295
#
# Add data point: 3.546688823311152
# Mean=3.2012408542892956  Variance=5.318687208000661
#
# Add data point: 2.523701859353512
# Mean=3.190133657651004  Variance=5.237567980047514
#
# Add data point: 1.274382589103388
# Mean=3.1592344468679783  Variance=5.210901405957658
#
# Add data point: 2.7530639042682314
# Mean=3.1527872953981406  Variance=5.129473252098099
#
# Add data point: 7.127246747185595
# Mean=3.21488822433232  Variance=5.294870665714561
#
# Add data point: 2.7762820262921344
# Mean=3.2081404366701634  Variance=5.215097933054452
#
# Add data point: -0.5491688896520319
# Mean=3.1512115074834632  Variance=5.348765253732029
#
# Add data point: 4.9825395647395485
# Mean=3.1785447620693748  Variance=5.317779511967515
#
# Add data point: 0.6980447403488172
# Mean=3.1420668205734845  Variance=5.3288932031781915
#
# Add data point: 3.1818286772535163
# Mean=3.1426430793659486  Variance=5.250550039780383
#
# Add data point: 2.060951227243099
# Mean=3.1271903386213364  Variance=5.191170215424037
#
# Add data point: 7.040291483365983
# Mean=3.182304439251543  Variance=5.332677691185612
#
# Add data point: 5.831548544760731
# Mean=3.219099496272504  Variance=5.355048642614696
#
# Add data point: 2.4379982529596784
# Mean=3.2083994792408213  Variance=5.289030763629743
#
# Add data point: 1.304846972186805
# Mean=3.182675796713064  Variance=5.2655446677820095
#
# Add data point: 0.33204702239830697
# Mean=3.1446674130555343  Variance=5.302736450877279
#
# Add data point: 5.51708143879556
# Mean=3.1758833870784295  Variance=5.306090512797965
#
# Add data point: -0.6752957755605551
# Mean=3.125868073277923  Variance=5.428891466687772
#
# Add data point: 3.885831673629088
# Mean=3.1356111963593483  Variance=5.365790801600439
#
# Add data point: 5.5824589977073025
# Mean=3.1665839533384363  Variance=5.372784234152296
#
# Add data point: 5.349406416561282
# Mean=3.193869234128722  Variance=5.364333230962086
#
# Add data point: 2.3977902623911813
# Mean=3.1840410986751726  Variance=5.305103037541018
#
# Add data point: 4.993493608626765
# Mean=3.2061075926989724  Variance=5.279536211309314
#
# Add data point: 7.315715796583464
# Mean=3.255620944553002  Variance=5.418632100347662
#
# Add data point: 4.007922333119753
# Mean=3.2645769134645115  Variance=5.360084964095176
#
# Add data point: 1.6676749690968178
# Mean=3.245789831766068  Variance=5.326275556101569
#
# Add data point: 3.2624877832473005
# Mean=3.245983993992594  Variance=5.263616732847104
#
# Add data point: 4.065158392473175
# Mean=3.255399791676279  Variance=5.210125067520074
#
# Add data point: 6.875770162676872
# Mean=3.2965403640740125  Variance=5.299182681845867
#
# Add data point: 8.949972768036933
# Mean=3.3600620764780906  Variance=5.598080404085317
#
# Add data point: 5.043396708046756
# Mean=3.3787657946066316  Variance=5.566665240729003
#
# Add data point: 3.1002903795880594
# Mean=3.375705625210823  Variance=5.50566558666343
#
# Add data point: 1.140153959932142
# Mean=3.351406150588229  Variance=5.499486497987701
#
# Add data point: 5.446671411436483
# Mean=3.3739358845758445  Variance=5.486915239796061
#
# Add data point: -2.72621495741112
# Mean=3.309040662852579  Variance=5.823786792632212
#
# Add data point: 1.601554591975134
# Mean=3.2910671252643953  Variance=5.792521179063406
#
# Add data point: 2.0667895363235598
# Mean=3.278314233712928  Variance=5.747160351236028
#
# Add data point: 3.0796870197065815
# Mean=3.2762665304757492  Variance=5.687700827166431
#
# Add data point: 5.14720217151673
# Mean=3.295357710486371  Variance=5.664783105276121
#
# Add data point: 3.715342724713673
# Mean=3.299599983357354  Variance=5.6087608870706855
#
# Add data point: 4.231847122139344
# Mean=3.308922454745174  Variance=5.560797583973906
#
# Add data point: 5.100368012154902
# Mean=3.326659539472003  Variance=5.536964629769446
#
# Add data point: 0.3401879773398515
# Mean=3.2973804065099226  Variance=5.569584495746668
#
# Add data point: 3.7569221070978522
# Mean=3.3018419764185434  Variance=5.517031003603624
#
# Add data point: 1.549952169624488
# Mean=3.2849968821224467  Variance=5.492978344793466
#
# Add data point: 1.3849184415944693
# Mean=3.2669008969745614  Variance=5.474545036563908
#
# Add data point: 2.576067135414906
# Mean=3.2603835973372064  Variance=5.426908883029842
#
# Add data point: 0.47140716095323665
# Mean=3.234318396997169  Variance=5.448406858974344
#
# Add data point: 1.9969788577089742
# Mean=3.222861549411167  Variance=5.411663179217315
#
# Add data point: 0.5569680490570059
# Mean=3.1984038108758077  Variance=5.426756913011929
#
# Add data point: 6.220366549263697
# Mean=3.2258761994066067  Variance=5.459990686816686
#
# Add data point: 1.6988784606383798
# Mean=3.2121194630213075  Variance=5.431360913198809
#
# Add data point: 6.2187753264202374
# Mean=3.238964604658798  Variance=5.463143836308756
#
# Add data point: 2.635392534825942
# Mean=3.233623258908065  Variance=5.417589653452175
#
# Add data point: 0.6865006775429277
# Mean=3.211280078369774  Variance=5.426557201871286
#
# Add data point: 4.361490402570858
# Mean=3.2212819072758703  Variance=5.390460029776188
#
# Add data point: -1.4968403612594274
# Mean=3.1806084394436693  Variance=5.5354888586175335
#
# Add data point: 0.7399088047196649
# Mean=3.1597477588050027  Variance=5.5386837826926145
#
# Add data point: 3.563676072900374
# Mean=3.1631708801108958  Variance=5.492727300680797
#
# Add data point: 2.1415480308145534
# Mean=3.154585814150422  Variance=5.454949463782285
#
# Add data point: 1.8506314014614933
# Mean=3.1437195273780145  Variance=5.423278694908355
#
# Add data point: 4.933671396971563
# Mean=3.1585125180358125  Variance=5.404563447068923
#
# Add data point: 0.5134897726323038
# Mean=3.1368320037292263  Variance=5.4172430869297505
#
# Add data point: 5.930517356427614
# Mean=3.1595448927755547  Variance=5.436292120515859
#
# Add data point: 2.987969225278958
# Mean=3.158161218037679  Variance=5.392332028517846
#
# Add data point: 3.612181924534378
# Mean=3.1617933836896523  Variance=5.350494558316189
#
# Add data point: -0.3146280045107779
# Mean=3.134202737751554  Variance=5.403607313503131
#
# Add data point: 4.556849393895305
# Mean=3.1454046799259134  Variance=5.376657946750412
#
# Add data point: 1.0873667702513585
# Mean=3.1293262587565813  Variance=5.367412057700119
#
# Add data point: 2.0821846607121426
# Mean=3.1212088820275548  Variance=5.3339791938392995
#
# Add data point: 2.53893979874676
# Mean=3.1167298890792408  Variance=5.295238497036101
#
# Add data point: 2.839353718405674
# Mean=3.1146125137305876  Variance=5.255093202678834
#
# Add data point: 2.659116445656257
# Mean=3.1111617859421457  Variance=5.2165497803308405
#
# Add data point: 7.108236585742277
# Mean=3.1412149799256053  Variance=5.297155328137973
#
# Add data point: -0.9068007355475824
# Mean=3.1110059074220744  Variance=5.379613892832227
#
# Add data point: 4.0660393264314845
# Mean=3.1180802290443665  Variance=5.3462237340637655
#
# Add data point: 0.7567435853632536
# Mean=3.100717459605535  Variance=5.347621420486104
#
# Add data point: 7.3858008635864225
# Mean=3.1319954406564903  Variance=5.442329432258712
#
# Add data point: 4.5373689481351045
# Mean=3.142179306652712  Variance=5.416916535381265
#
# Add data point: 0.9802132186777301
# Mean=3.1266255937895826  Variance=5.411290116761123
#
# Add data point: 3.9652426361502657
# Mean=3.1326157155207306  Variance=5.377383390205778
#
# Add data point: 0.7607720550630246
# Mean=3.1157941292763494  Variance=5.378871681539743
#
# Add data point: -1.5459305275977622
# Mean=3.0829650823969543  Variance=5.493763632728884
#
# Add data point: 2.897326398307489
# Mean=3.0816669097809437  Variance=5.45531614749822
#
# Add data point: 5.584986666811403
# Mean=3.099051074760322  Variance=5.460685207182054
#
# Add data point: 5.334887519086358
# Mean=3.114470636445329  Variance=5.457239400103052
#
# Add data point: 1.4396176669111207
# Mean=3.102999040763588  Variance=5.438816502402096
#
# Add data point: 3.356040622486788
# Mean=3.104720412067828  Variance=5.401999913094983
#
# Add data point: 3.4717697609823093
# Mean=3.1072004752361684  Variance=5.366161919937653
#
# Add data point: 0.9555721497148593
# Mean=3.092760016675623  Variance=5.360974568799651
#
# Add data point: 1.4583087667767414
# Mean=3.08186367500963  Variance=5.342804412962342
#
# Add data point: 4.3521851999276
# Mean=3.0902764003402123  Variance=5.317872582946588
#
# Add data point: 1.2644879354097887
# Mean=3.0782646341235647  Variance=5.3045858279235745
#
# Add data point: 4.642411112882595
# Mean=3.088487813723297  Variance=5.285677787323034
#
# Add data point: 1.25091067509079
# Mean=3.076555494641268  Variance=5.273057430436405
#
# Add data point: 5.5339662308342294
# Mean=3.0924097574554157  Variance=5.277777233425147
#
# Add data point: 4.470489217866658
# Mean=3.1012436001503594  Variance=5.255900794900038
#
# Add data point: 1.2298267945996215
# Mean=3.089323747885705  Variance=5.244516134985615
#
# Add data point: 1.746585782251675
# Mean=3.0808254063310594  Variance=5.222522619466627
#
# Add data point: 5.092409679195417
# Mean=3.0934768797453005  Variance=5.214918183785739
#
# Add data point: 1.0598070852395955
# Mean=3.08076644352964  Variance=5.207968786421541
#
# Add data point: 2.75030774826651
# Mean=3.0787139050497445  Variance=5.1760972606944495
#
# Add data point: 0.8189762922852286
# Mean=3.0647649074400873  Variance=5.175468662826679
#
# Add data point: -0.7403939678821896
# Mean=3.04142037446265  Variance=5.232350982251173
#
# Add data point: 3.384046699571098
# Mean=3.0435095593718478  Variance=5.2009664792245385
#
# Add data point: 1.9080374076606055
# Mean=3.0366279099675375  Variance=5.1770671902417975
#
# Add data point: 2.8876727145203747
# Mean=3.035730589513036  Variance=5.145824685996133
#
# Add data point: 2.6064284022886905
# Mean=3.0331599177332498  Variance=5.115929337122285
#
# Add data point: 4.641805771043573
# Mean=3.042735190669621  Variance=5.100698252817777
#
# Add data point: 3.0322583910364607
# Mean=3.0426731977723827  Variance=5.070337603181025

# %% [markdown]
# # 3. Baysian Linear regression

# %%
import random
import math
import numpy as np

def polynomial_basis_generator(n, a, w):
    x0 = random.uniform(-1,1)
    x = [math.pow(x0,i) for i in range(len(w))]
    y = np.sum(w*x)
    e = gaussian_data_generator(0,a)
    return x0, y+e

# %%
b=1 #prior gaussian distribution's variance
n=3 #basis
a=3 #variance of N(0,a)
w=np.asarray([1, 2, 3]) #line parameters

# %%
NUM=1000
point_x=[]
point_y=[]

# after 10 points, after 50 points, final result
mean_list=[]
variance_list=[]

# %%
mean = np.zeros((n, 1))
variance = (1/b) * np.identity(n)
count = 0
eps = 1
while count <= NUM:
    point = polynomial_basis_generator(n, a, w)
    new_x = point[0]
    new_y = point[1]

    print('Add data point {}:'.format(point))
    print()
    X = np.asarray([math.pow(new_x,i) for i in range(n)])
    S = np.linalg.pinv(variance)
    X = X.reshape(1, -1)
    
    # Predict_distribution ~N(mean^T@X^t, 1/a(a為precision)+X@variance@X^T)
    predicted_mean = mean.T.dot(X.T).item()
    predicted_variance = ((a) + X@variance@X.T).item()
    
    # Posterier ~N(variance_new@(a(a為precision)@X^T@y+S@mean, a@X^t@X+bI)
    variance_new = np.linalg.pinv((1/a) * X.T@X + S)
    mean_new = variance_new@((1/a) * X.T * new_y + S@mean)
    
    print('Posterior mean:')
    print(mean_new)
    print()
    print('Posterior variance:')
    print(variance_new)
    print()

    print('Predictive distribution ~ N({:.5f},{:.5f})'.format(predicted_mean, predicted_variance))
    print('--------------------------------------------------')

    point_x.append(new_x)
    point_y.append(new_y)
    if count==10 or count==50 or count==NUM:
        mean_list.append(mean_new)
        variance_list.append(variance_new)

    mean=mean_new
    variance = variance_new
    count += 1
# Out:
# Add data point (0.3814750514757903, 2.8655863376582538):
#
# Posterior mean:
# [[0.68773518]
#  [0.26235381]
#  [0.10008143]]
#
# Posterior variance:
# [[ 0.76000193 -0.09155328 -0.03492529]
#  [-0.09155328  0.96507471 -0.01332313]
#  [-0.03492529 -0.01332313  0.99491756]]
#
# Predictive distribution ~ N(0.00000,4.16670)
# --------------------------------------------------
# Add data point (-0.26627585781728613, 0.857401330688315):
#
# Posterior mean:
# [[0.73460191]
#  [0.24140661]
#  [0.10242894]]
#
# Posterior variance:
# [[ 0.60233939 -0.0210856  -0.04282245]
#  [-0.0210856   0.933579   -0.00979347]
#  [-0.04282245 -0.00979347  0.994522  ]]
#
# Predictive distribution ~ N(0.62497,3.87774)
# --------------------------------------------------
# Add data point (0.8344089577728315, 4.093808099192455):
#
# Posterior mean:
# [[1.10467245]
#  [0.74228625]
#  [0.53018392]]
#
# Posterior variance:
# [[ 0.53580246 -0.11114138 -0.11973077]
#  [-0.11114138  0.81169114 -0.11388662]
#  [-0.11973077 -0.11388662  0.90562567]]
#
# Predictive distribution ~ N(1.00735,4.62823)
# --------------------------------------------------
# Add data point (-0.995997012096459, 1.7942514520466517):
#
# Posterior mean:
# [[1.19224774]
#  [0.57093419]
#  [0.67822512]]
#
# Posterior variance:
# [[ 0.48461928 -0.01099505 -0.20625311]
#  [-0.01099505  0.61574225  0.05540523]
#  [-0.20625311  0.05540523  0.75936441]]
#
# Predictive distribution ~ N(0.89131,5.44111)
# --------------------------------------------------
# Add data point (-0.8250892030238692, -0.3144521248166212):
#
# Posterior mean:
# [[1.0576744 ]
#  [0.75428093]
#  [0.57728485]]
#
# Posterior variance:
# [[ 0.45286839  0.03226332 -0.2300687 ]
#  [ 0.03226332  0.55680575  0.08785231]
#  [-0.2300687   0.08785231  0.7415009 ]]
#
# Predictive distribution ~ N(1.18289,3.93081)
# --------------------------------------------------
# Add data point (0.20887969659627892, 0.791071145531793):
#
# Posterior mean:
# [[0.99951776]
#  [0.73456612]
#  [0.60048776]]
#
# Posterior variance:
# [[ 0.39468263  0.01253864 -0.20685418]
#  [ 0.01253864  0.55011919  0.09572192]
#  [-0.20685418  0.09572192  0.73223894]]
#
# Predictive distribution ~ N(1.24042,3.47358)
# --------------------------------------------------
# Add data point (0.33800021273448344, 0.8505889989869351):
#
# Posterior mean:
# [[0.94863574]
#  [0.70617347]
#  [0.61280477]]
#
# Posterior variance:
# [[ 0.35368895 -0.01033623 -0.19693084]
#  [-0.01033623  0.53735479  0.10125923]
#  [-0.19693084  0.10125923  0.7298368 ]]
#
# Predictive distribution ~ N(1.31640,3.43569)
# --------------------------------------------------
# Add data point (0.9523159637104857, 7.314846958603882):
#
# Posterior mean:
# [[1.1489123 ]
#  [1.42515174]
#  [1.29319999]]
#
# Posterior variance:
# [[ 0.34724761 -0.03346014 -0.21881384]
#  [-0.03346014  0.45434161  0.02270085]
#  [-0.21881384  0.02270085  0.65549415]]
#
# Predictive distribution ~ N(2.17689,4.23932)
# --------------------------------------------------
# Add data point (-0.31445129759509616, 0.9970014121083133):
#
# Posterior mean:
# [[1.16568028]
#  [1.41646757]
#  [1.28516167]]
#
# Posterior variance:
# [[ 0.31376988 -0.01612197 -0.20276511]
#  [-0.01612197  0.44536215  0.01438919]
#  [-0.20276511  0.01438919  0.64780063]]
#
# Predictive distribution ~ N(0.82864,3.37494)
# --------------------------------------------------
# Add data point (0.33906282900729123, 3.047064242171227):
#
# Posterior mean:
# [[1.27336481]
#  [1.46805844]
#  [1.23853017]]
#
# Posterior variance:
# [[ 0.28928435 -0.02785281 -0.19216195]
#  [-0.02785281  0.43974199  0.01946909]
#  [-0.19216195  0.01946909  0.64320905]]
#
# Predictive distribution ~ N(1.79370,3.31710)
# --------------------------------------------------
# Add data point (-0.9728676565547867, 3.9994114820483753):
#
# Posterior mean:
# [[1.37526365]
#  [1.13681653]
#  [1.5398019 ]]
#
# Posterior variance:
# [[ 0.28468817 -0.01291206 -0.20575088]
#  [-0.01291206  0.39117419  0.06364255]
#  [-0.20575088  0.06364255  0.60303232]]
#
# Predictive distribution ~ N(1.01737,3.93627)
# --------------------------------------------------
# Add data point (-0.1636884636146867, 2.7667070338489537):
#
# Posterior mean:
# [[1.50668194]
#  [1.10166551]
#  [1.44635674]]
#
# Posterior variance:
# [[ 0.26062567 -0.00647596 -0.1886412 ]
#  [-0.00647596  0.3894527   0.05906615]
#  [-0.1886412   0.05906615  0.59086646]]
#
# Predictive distribution ~ N(1.23044,3.28825)
# --------------------------------------------------
# Add data point (-0.2971656098928175, -0.08166008902558797):
#
# Posterior mean:
# [[1.40216369]
#  [1.15139388]
#  [1.51182238]]
#
# Posterior variance:
# [[ 0.24211888  0.00232932 -0.17704937]
#  [ 0.00232932  0.38526327  0.05355092]
#  [-0.17704937  0.05355092  0.58360584]]
#
# Predictive distribution ~ N(1.30703,3.26706)
# --------------------------------------------------
# Add data point (-0.7571903455083506, -0.4497924651788945):
#
# Posterior mean:
# [[1.32678099]
#  [1.2918401 ]
#  [1.44829754]]
#
# Posterior variance:
# [[ 0.23645181  0.01288769 -0.18182499]
#  [ 0.01288769  0.36559187  0.06244843]
#  [-0.18182499  0.06244843  0.57958143]]
#
# Predictive distribution ~ N(1.39712,3.40180)
# --------------------------------------------------
# Add data point (0.1773324778870129, 1.85363722389638):
#
# Posterior mean:
# [[1.34490786]
#  [1.29803872]
#  [1.43643245]]
#
# Posterior variance:
# [[ 0.21970532  0.00716109 -0.17086343]
#  [ 0.00716109  0.36363362  0.06619682]
#  [-0.17086343  0.06619682  0.57240645]]
#
# Predictive distribution ~ N(1.60141,3.24235)
# --------------------------------------------------
# Add data point (0.7653802595008763, 5.938146593167588):
#
# Posterior mean:
# [[1.44351105]
#  [1.55363066]
#  [1.60599959]]
#
# Posterior variance:
# [[ 0.21523347 -0.00443052 -0.17855364]
#  [-0.00443052  0.33358669  0.04626281]
#  [-0.17855364  0.04626281  0.55918165]]
#
# Predictive distribution ~ N(3.17987,3.49929)
# --------------------------------------------------
# Add data point (0.21606890156698655, -1.4980710536513118):
#
# Posterior mean:
# [[1.22873716]
#  [1.48082934]
#  [1.75456181]]
#
# Posterior variance:
# [[ 0.20203917 -0.00890296 -0.16942696]
#  [-0.00890296  0.33207069  0.04935646]
#  [-0.16942696  0.04935646  0.55286858]]
#
# Predictive distribution ~ N(1.85418,3.21437)
# --------------------------------------------------
# Add data point (0.027307885594342718, 0.46982828687229916):
#
# Posterior mean:
# [[1.17830285]
#  [1.48077883]
#  [1.79649256]]
#
# Posterior variance:
# [[ 0.18933574 -0.00891568 -0.15886541]
#  [-0.00891568  0.33207067  0.04936704]
#  [-0.15886541  0.04936704  0.54408778]]
#
# Predictive distribution ~ N(1.27048,3.20155)
# --------------------------------------------------
# Add data point (0.22481341445442937, 1.730055429242245):
#
# Posterior mean:
# [[1.18550387]
#  [1.48351917]
#  [1.79166242]]
#
# Posterior variance:
# [[ 0.17925306 -0.01275264 -0.15210238]
#  [-0.01275264  0.33061052  0.05194071]
#  [-0.15210238  0.05194071  0.53955143]]
#
# Predictive distribution ~ N(1.60200,3.18856)
# --------------------------------------------------
# Add data point (0.3964749371522225, 1.0631954674906834):
#
# Posterior mean:
# [[1.13880824]
#  [1.44421741]
#  [1.80617121]]
#
# Posterior variance:
# [[ 0.17217956 -0.0187061  -0.14990457]
#  [-0.0187061   0.32559973  0.05379051]
#  [-0.14990457  0.05379051  0.53886855]]
#
# Predictive distribution ~ N(2.05532,3.19310)
# --------------------------------------------------
# Add data point (-0.13771600312509413, 0.6483834569681135):
#
# Posterior mean:
# [[1.12118338]
#  [1.45062773]
#  [1.82125144]]
#
# Posterior variance:
# [[ 0.16287924 -0.01532349 -0.141947  ]
#  [-0.01532349  0.32436945  0.05089627]
#  [-0.141947    0.05089627  0.53205987]]
#
# Predictive distribution ~ N(0.97417,3.17773)
# --------------------------------------------------
# Add data point (0.6694852120869452, 6.3660677345218595):
#
# Posterior mean:
# [[1.21448515]
#  [1.68613995]
#  [1.95816879]]
#
# Posterior variance:
# [[ 0.16047753 -0.02138589 -0.14547144]
#  [-0.02138589  0.30906675  0.04199989]
#  [-0.14547144  0.04199989  0.52688788]]
#
# Predictive distribution ~ N(2.90866,3.29793)
# --------------------------------------------------
# Add data point (0.10011376510829773, -0.06492399094532142):
#
# Posterior mean:
# [[1.14153358]
#  [1.6815005 ]
#  [2.02140486]]
#
# Posterior variance:
# [[ 0.15268068 -0.02188174 -0.13871296]
#  [-0.02188174  0.30903521  0.0424297 ]
#  [-0.13871296  0.0424297   0.52102947]]
#
# Predictive distribution ~ N(1.40292,3.15651)
# --------------------------------------------------
# Add data point (0.7524861281425359, 3.6787524506319):
#
# Posterior mean:
# [[1.14373144]
#  [1.6904446 ]
#  [2.02857881]]
#
# Posterior variance:
# [[ 0.15168515 -0.02593299 -0.14196241]
#  [-0.02593299  0.29254887  0.02920624]
#  [-0.14196241  0.02920624  0.51042311]]
#
# Predictive distribution ~ N(3.55143,3.34086)
# --------------------------------------------------
# Add data point (-0.0381989641375724, 1.5526129672783568):
#
# Posterior mean:
# [[1.16647813]
#  [1.68491484]
#  [2.00734421]]
#
# Posterior variance:
# [[ 0.14431386 -0.02414101 -0.13508112]
#  [-0.02414101  0.29211324  0.02753338]
#  [-0.13508112  0.02753338  0.50399926]]
#
# Predictive distribution ~ N(1.08212,3.15368)
# --------------------------------------------------
# Add data point (0.07647581217966049, 2.8742197569521934):
#
# Posterior mean:
# [[1.23717036]
#  [1.68409634]
#  [1.94246483]]
#
# Posterior variance:
# [[ 0.13792294 -0.02406702 -0.12921571]
#  [-0.02406702  0.29211238  0.02746547]
#  [-0.12921571  0.02746547  0.49861615]]
#
# Predictive distribution ~ N(1.30707,3.14079)
# --------------------------------------------------
# Add data point (0.4737759578450551, 4.380456372485879):
#
# Posterior mean:
# [[1.29621212]
#  [1.75704994]
#  [1.93987226]]
#
# Posterior variance:
# [[ 0.13490756 -0.0277929  -0.1290833 ]
#  [-0.0277929   0.28750857  0.02762908]
#  [-0.1290833   0.02762908  0.49861033]]
#
# Predictive distribution ~ N(2.47107,3.15364)
# --------------------------------------------------
# Add data point (0.9680820744660497, 7.3658533261195895):
#
# Posterior mean:
# [[1.28701207]
#  [1.95308843]
#  [2.19868711]]
#
# Posterior variance:
# [[ 1.34860763e-01 -2.67958307e-02 -1.27766943e-01]
#  [-2.67958307e-02  2.66262520e-01 -4.20486652e-04]
#  [-1.27766943e-01 -4.20486652e-04  4.61578606e-01]]
#
# Predictive distribution ~ N(4.81520,3.59666)
# --------------------------------------------------
# Add data point (0.7934744866211925, 0.9356832621009454):
#
# Posterior mean:
# [[1.25381792]
#  [1.76866817]
#  [2.03599322]]
#
# Posterior variance:
# [[ 0.13452576 -0.02865705 -0.12940889]
#  [-0.02865705  0.25592195 -0.00954285]
#  [-0.12940889 -0.00954285  0.45353094]]
#
# Predictive distribution ~ N(4.22104,3.28164)
# --------------------------------------------------
# Add data point (-0.8903272085919232, 2.855667203162927):
#
# Posterior mean:
# [[1.27960681]
#  [1.65014653]
#  [2.14307794]]
#
# Posterior variance:
# [[ 0.13357748 -0.02429892 -0.13334648]
#  [-0.02429892  0.23589266  0.00855369]
#  [-0.13334648  0.00855369  0.43718066]]
#
# Predictive distribution ~ N(1.29302,3.48170)
# --------------------------------------------------
# Add data point (0.4373401091451887, 0.9690159811449428):
#
# Posterior mean:
# [[1.23461978]
#  [1.61298165]
#  [2.16430868]]
#
# Posterior variance:
# [[ 0.13053774 -0.02681012 -0.13191194]
#  [-0.02681012  0.2338181   0.0097388 ]
#  [-0.13191194  0.0097388   0.43650366]]
#
# Predictive distribution ~ N(2.41118,3.12386)
# --------------------------------------------------
# Add data point (-0.24441013763300368, 1.2498564008932556):
#
# Posterior mean:
# [[1.2461376 ]
#  [1.60554953]
#  [2.15466222]]
#
# Posterior variance:
# [[ 0.12522604 -0.02338262 -0.12746325]
#  [-0.02338262  0.23160643  0.00686819]
#  [-0.12746325  0.00686819  0.43277777]]
#
# Predictive distribution ~ N(0.96968,3.14312)
# --------------------------------------------------
# Add data point (-0.32702809783863573, 0.5181100829765154):
#
# Posterior mean:
# [[1.22969225]
#  [1.61911916]
#  [2.16616792]]
#
# Posterior variance:
# [[ 0.12070148 -0.01964925 -0.12429772]
#  [-0.01964925  0.2285259   0.00425619]
#  [-0.12429772  0.00425619  0.43056306]]
#
# Predictive distribution ~ N(0.95151,3.14250)
# --------------------------------------------------
# Add data point (0.24282369227268497, 1.2812902698378024):
#
# Posterior mean:
# [[1.21331315]
#  [1.61367562]
#  [2.18092958]]
#
# Posterior variance:
# [[ 0.11691107 -0.02090898 -0.12088162]
#  [-0.02090898  0.22810723  0.00539153]
#  [-0.12088162  0.00539153  0.42748429]]
#
# Predictive distribution ~ N(1.75058,3.11159)
# --------------------------------------------------
# Add data point (-0.3764076727893835, 2.247020887551834):
#
# Posterior mean:
# [[1.25900289]
#  [1.56868537]
#  [2.15447017]]
#
# Posterior variance:
# [[ 0.11321865 -0.01727308 -0.11874329]
#  [-0.01727308  0.224527    0.00328594]
#  [-0.11874329  0.00328594  0.42624597]]
#
# Predictive distribution ~ N(0.91491,3.13872)
# --------------------------------------------------
# Add data point (0.7046605339011296, 2.8495752379995434):
#
# Posterior mean:
# [[1.25128973]
#  [1.54255533]
#  [2.13701827]]
#
# Posterior variance:
# [[ 0.11266339 -0.01915415 -0.11999963]
#  [-0.01915415  0.21815447 -0.00097018]
#  [-0.11999963 -0.00097018  0.42340336]]
#
# Predictive distribution ~ N(3.43419,3.18983)
# --------------------------------------------------
# Add data point (-0.17868600063211915, 1.9540154703655008):
#
# Posterior mean:
# [[1.28404303]
#  [1.52558375]
#  [2.10600017]]
#
# Posterior variance:
# [[ 0.10862361 -0.01706088 -0.11617387]
#  [-0.01706088  0.21706982 -0.00295255]
#  [-0.11617387 -0.00295255  0.41978028]]
#
# Predictive distribution ~ N(1.04389,3.11925)
# --------------------------------------------------
# Add data point (-0.6239534963713056, 1.023742167920047):
#
# Posterior mean:
# [[1.281064  ]
#  [1.53176597]
#  [2.10402477]]
#
# Posterior variance:
# [[ 0.10690461 -0.01349352 -0.11731375]
#  [-0.01349352  0.20966665 -0.00058702]
#  [-0.11731375 -0.00058702  0.41902443]]
#
# Predictive distribution ~ N(1.15205,3.18903)
# --------------------------------------------------
# Add data point (-0.33044520177092096, 1.2418856613388924):
#
# Posterior mean:
# [[1.28856232]
#  [1.52546312]
#  [2.09859506]]
#
# Posterior variance:
# [[ 0.10378967 -0.0108752  -0.11505816]
#  [-0.0108752   0.20746578 -0.002483  ]
#  [-0.11505816 -0.002483    0.4173911 ]]
#
# Predictive distribution ~ N(1.00465,3.11814)
# --------------------------------------------------
# Add data point (0.9469186605500659, 3.7624551580949985):
#
# Posterior mean:
# [[1.29099194]
#  [1.4794226 ]
#  [2.03409963]]
#
# Posterior variance:
# [[ 0.10376209 -0.01035253 -0.11432598]
#  [-0.01035253  0.19756142 -0.01635743]
#  [-0.11432598 -0.01635743  0.39795524]]
#
# Predictive distribution ~ N(4.61477,3.39425)
# --------------------------------------------------
# Add data point (0.9444924055466926, 5.338072325410502):
#
# Posterior mean:
# [[1.28899422]
#  [1.51977867]
#  [2.09032742]]
#
# Posterior variance:
# [[ 0.10374295 -0.00996589 -0.11378728]
#  [-0.00996589  0.18975085 -0.02723983]
#  [-0.11378728 -0.02723983  0.38279286]]
#
# Predictive distribution ~ N(4.50285,3.34559)
# --------------------------------------------------
# Add data point (0.1468649805547919, 1.5469119726948317):
#
# Posterior mean:
# [[1.28866024]
#  [1.51972074]
#  [2.09069387]]
#
# Posterior variance:
# [[ 0.10052843 -0.01052344 -0.1102602 ]
#  [-0.01052344  0.18965415 -0.02662807]
#  [-0.1102602  -0.02662807  0.37892284]]
#
# Predictive distribution ~ N(1.55728,3.10001)
# --------------------------------------------------
# Add data point (-0.06791112742290428, -0.5786359148343665):
#
# Posterior mean:
# [[1.23105696]
#  [1.53317359]
#  [2.15171084]]
#
# Posterior variance:
# [[ 0.097257   -0.00975942 -0.1067949 ]
#  [-0.00975942  0.18947571 -0.02743737]
#  [-0.1067949  -0.02743737  0.37525218]]
#
# Predictive distribution ~ N(1.19510,3.10184)
# --------------------------------------------------
# Add data point (0.29420852415898824, 0.41197973339976435):
#
# Posterior mean:
# [[1.19093835]
#  [1.51262416]
#  [2.19053093]]
#
# Posterior variance:
# [[ 0.09491165 -0.01096075 -0.10452546]
#  [-0.01096075  0.18886037 -0.02627493]
#  [-0.10452546 -0.02627493  0.37305619]]
#
# Predictive distribution ~ N(1.86838,3.09084)
# --------------------------------------------------
# Add data point (-0.0942626472105732, 1.517798138205106):
#
# Posterior mean:
# [[1.20474432]
#  [1.5084109 ]
#  [2.17618474]]
#
# Posterior variance:
# [[ 0.09199643 -0.01007109 -0.10149618]
#  [-0.01007109  0.18858887 -0.02719939]
#  [-0.10149618 -0.02719939  0.36990837]]
#
# Predictive distribution ~ N(1.06782,3.09687)
# --------------------------------------------------
# Add data point (0.5332330848938558, 2.6027464878260274):
#
# Posterior mean:
# [[1.20427635]
#  [1.50774049]
#  [2.1762724 ]]
#
# Posterior variance:
# [[ 0.09091956 -0.01161381 -0.10129446]
#  [-0.01161381  0.18637877 -0.02691041]
#  [-0.10129446 -0.02691041  0.36987059]]
#
# Predictive distribution ~ N(2.62785,3.09882)
# --------------------------------------------------
# Add data point (-0.8194173646765719, 2.9929270712949823):
#
# Posterior mean:
# [[1.21965285]
#  [1.4212343 ]
#  [2.25647074]]
#
# Posterior variance:
# [[ 0.09060057 -0.0098192  -0.10295821]
#  [-0.0098192   0.17628253 -0.01755037]
#  [-0.10295821 -0.01755037  0.36119306]]
#
# Predictive distribution ~ N(1.43005,3.29543)
# --------------------------------------------------
# Add data point (0.46241940309618434, 1.3798572013454795):
#
# Posterior mean:
# [[1.19933965]
#  [1.39968406]
#  [2.2672037 ]]
#
# Posterior variance:
# [[ 0.08927241 -0.01122825 -0.10225644]
#  [-0.01122825  0.17478768 -0.01680587]
#  [-0.10225644 -0.01680587  0.36082227]]
#
# Predictive distribution ~ N(2.35936,3.08823)
# --------------------------------------------------
# Add data point (0.5831842388982729, 4.216409051802635):
#
# Posterior mean:
# [[1.22144431]
#  [1.43886657]
#  [2.27211812]]
#
# Posterior variance:
# [[ 0.08853111 -0.01254227 -0.10242125]
#  [-0.01254227  0.17245847 -0.01709801]
#  [-0.10242125 -0.01709801  0.36078563]]
#
# Predictive distribution ~ N(2.78670,3.10114)
# --------------------------------------------------
# Add data point (-0.2960855524593189, 3.7545987475738833):
#
# Posterior mean:
# [[1.29565461]
#  [1.3808432 ]
#  [2.21353659]]
#
# Posterior variance:
# [[ 0.08629227 -0.01079177 -0.10065391]
#  [-0.01079177  0.17108979 -0.01847985]
#  [-0.10065391 -0.01847985  0.35939049]]
#
# Predictive distribution ~ N(0.99461,3.09678)
# --------------------------------------------------
# Add data point (0.18416978936832074, 1.4401089849993078):
#
# Posterior mean:
# [[1.29079994]
#  [1.37963743]
#  [2.21905002]]
#
# Posterior variance:
# [[ 0.08416884 -0.01131917 -0.09824233]
#  [-0.01131917  0.1709588  -0.01788088]
#  [-0.09824233 -0.01788088  0.35665167]]
#
# Predictive distribution ~ N(1.62504,3.08147)
# --------------------------------------------------
# Add data point (0.22705893137220956, 1.900309196711936):
#
# Posterior mean:
# [[1.29532113]
#  [1.38120744]
#  [2.21409279]]
#
# Posterior variance:
# [[ 0.08226599 -0.01197994 -0.09615597]
#  [-0.01197994  0.17072934 -0.01715638]
#  [-0.09615597 -0.01715638  0.3543641 ]]
#
# Predictive distribution ~ N(1.71846,3.07824)
# --------------------------------------------------
# Add data point (0.5593639282286849, 2.293477961856055):
#
# Posterior mean:
# [[1.28844657]
#  [1.36939402]
#  [2.21331831]]
#
# Posterior variance:
# [[ 0.08159681 -0.01312989 -0.09623136]
#  [-0.01312989  0.16875325 -0.01728593]
#  [-0.09623136 -0.01728593  0.3543556 ]]
#
# Predictive distribution ~ N(2.76068,3.09080)
# --------------------------------------------------
# Add data point (0.35411659032979625, 1.430373205656767):
#
# Posterior mean:
# [[1.27534658]
#  [1.3604169 ]
#  [2.22501237]]
#
# Posterior variance:
# [[ 0.08022716 -0.01406847 -0.09500871]
#  [-0.01406847  0.16811005 -0.01644808]
#  [-0.09500871 -0.01644808  0.35326417]]
#
# Predictive distribution ~ N(2.05092,3.07336)
# --------------------------------------------------
# Add data point (-0.7883937411558133, 1.5126274568579108):
#
# Posterior mean:
# [[1.27461831]
#  [1.36395681]
#  [2.22190795]]
#
# Posterior variance:
# [[ 0.079906   -0.01250741 -0.09637773]
#  [-0.01250741  0.16052217 -0.00979368]
#  [-0.09637773 -0.00979368  0.34742842]]
#
# Predictive distribution ~ N(1.58579,3.24139)
# --------------------------------------------------
# Add data point (-0.7720826206335667, 3.0085925245361853):
#
# Posterior mean:
# [[1.28923755]
#  [1.29917961]
#  [2.27576222]]
#
# Posterior variance:
# [[ 0.07958503 -0.01108521 -0.09756012]
#  [-0.01108521  0.15422045 -0.00455457]
#  [-0.09756012 -0.00455457  0.34307274]]
#
# Predictive distribution ~ N(1.54604,3.21248)
# --------------------------------------------------
# Add data point (-0.12960983761319955, 0.06282904805112055):
#
# Posterior mean:
# [[1.26100042]
#  [1.31025998]
#  [2.30820513]]
#
# Posterior variance:
# [[ 0.0775403  -0.01028285 -0.09521083]
#  [-0.01028285  0.1539056  -0.00547645]
#  [-0.09521083 -0.00547645  0.34037354]]
#
# Predictive distribution ~ N(1.15908,3.08189)
# --------------------------------------------------
# Add data point (-0.32340978555472466, 1.4016803858676323):
#
# Posterior mean:
# [[1.26842588]
#  [1.30391076]
#  [2.30214823]]
#
# Posterior variance:
# [[ 0.07591024 -0.00888904 -0.0938812 ]
#  [-0.00888904  0.15271382 -0.00661336]
#  [-0.0938812  -0.00661336  0.33928897]]
#
# Predictive distribution ~ N(1.07867,3.08447)
# --------------------------------------------------
# Add data point (0.7269110196589237, 3.202359798744185):
#
# Posterior mean:
# [[1.26696756]
#  [1.29666208]
#  [2.29622501]]
#
# Posterior variance:
# [[ 0.07578462 -0.00951344 -0.09439142]
#  [-0.00951344  0.14961022 -0.00914945]
#  [-0.09439142 -0.00914945  0.33721661]]
#
# Predictive distribution ~ N(3.43271,3.13412)
# --------------------------------------------------
# Add data point (0.35780794196246557, 1.0196301690008849):
#
# Posterior mean:
# [[1.24721495]
#  [1.2826257 ]
#  [2.31407642]]
#
# Posterior variance:
# [[ 0.07459986 -0.01035534 -0.09332069]
#  [-0.01035534  0.14901195 -0.00838859]
#  [-0.09332069 -0.00838859  0.33624895]]
#
# Predictive distribution ~ N(2.02490,3.06865)
# --------------------------------------------------
# Add data point (-0.2508615457439478, 2.454620092032351):
#
# Posterior mean:
# [[1.27926427]
#  [1.26093833]
#  [2.28259739]]
#
# Posterior variance:
# [[ 0.07294764 -0.0092373  -0.09169787]
#  [-0.0092373   0.14825539 -0.00948673]
#  [-0.09169787 -0.00948673  0.334655  ]]
#
# Predictive distribution ~ N(1.07108,3.07902)
# --------------------------------------------------
# Add data point (0.8190700493866303, 4.8486992052999):
#
# Posterior mean:
# [[1.28048787]
#  [1.29445315]
#  [2.32219699]]
#
# Posterior variance:
# [[ 0.07294294 -0.00936611 -0.09185007]
#  [-0.00936611  0.14472722 -0.01365546]
#  [-0.09185007 -0.01365546  0.32972942]]
#
# Predictive distribution ~ N(3.84340,3.17443)
# --------------------------------------------------
# Add data point (0.17663966605986592, 2.415979880118676):
#
# Posterior mean:
# [[1.29909276]
#  [1.29874184]
#  [2.29936348]]
#
# Posterior variance:
# [[ 0.07141727 -0.0097178  -0.08997764]
#  [-0.0097178   0.14464615 -0.01322384]
#  [-0.08997764 -0.01322384  0.32743141]]
#
# Predictive distribution ~ N(1.58160,3.06859)
# --------------------------------------------------
# Add data point (-0.5142387815477667, -1.5507674183840643):
#
# Posterior mean:
# [[1.25171149]
#  [1.37761716]
#  [2.29629388]]
#
# Posterior variance:
# [[ 0.07052365 -0.0082302  -0.09003553]
#  [-0.0082302   0.14216975 -0.01312746]
#  [-0.09003553 -0.01312746  0.32742766]]
#
# Predictive distribution ~ N(1.23928,3.09857)
# --------------------------------------------------
# Add data point (-0.6212530042744717, 0.2760650358117783):
#
# Posterior mean:
# [[1.23853224]
#  [1.41037276]
#  [2.2819525 ]]
#
# Posterior variance:
# [[ 0.06998803 -0.00689899 -0.09061837]
#  [-0.00689899  0.13886118 -0.01167887]
#  [-0.09061837 -0.01167887  0.32679342]]
#
# Predictive distribution ~ N(1.28213,3.12119)
# --------------------------------------------------
# Add data point (-0.6777317422428941, 1.2109694855595379):
#
# Posterior mean:
# [[1.23726948]
#  [1.41443817]
#  [2.27937661]]
#
# Posterior variance:
# [[ 0.06963993 -0.00577827 -0.09132847]
#  [-0.00577827  0.13525305 -0.00939273]
#  [-0.09132847 -0.00939273  0.3253449 ]]
#
# Predictive distribution ~ N(1.33082,3.13609)
# --------------------------------------------------
# Add data point (0.0038740431394459485, 1.3853680996573852):
#
# Posterior mean:
# [[1.2405032 ]
#  [1.4141941 ]
#  [2.27513288]]
#
# Posterior variance:
# [[ 0.06806108 -0.00565911 -0.08925649]
#  [-0.00565911  0.13524406 -0.00954911]
#  [-0.08925649 -0.00954911  0.32262576]]
#
# Predictive distribution ~ N(1.24278,3.06959)
# --------------------------------------------------
# Add data point (-0.08323979411450932, 3.1543428553372252):
#
# Posterior mean:
# [[1.28511447]
#  [1.4030383 ]
#  [2.21849246]]
#
# Posterior variance:
# [[ 0.06655809 -0.00528326 -0.08734823]
#  [-0.00528326  0.13515007 -0.01002631]
#  [-0.08734823 -0.01002631  0.32020295]]
#
# Predictive distribution ~ N(1.13855,3.06873)
# --------------------------------------------------
# Add data point (0.9776692418697441, 4.892933574594642):
#
# Posterior mean:
# [[1.28433859]
#  [1.40715562]
#  [2.22582758]]
#
# Posterior variance:
# [[ 0.06640977 -0.00449616 -0.08594599]
#  [-0.00449616  0.13097323 -0.01746746]
#  [-0.08594599 -0.01746746  0.30694632]]
#
# Predictive distribution ~ N(4.77734,3.29223)
# --------------------------------------------------
# Add data point (-0.9513066960848768, 2.5204417942420987):
#
# Posterior mean:
# [[1.28314114]
#  [1.3826928 ]
#  [2.26101978]]
#
# Posterior variance:
# [[ 0.06639461 -0.00480578 -0.08550058]
#  [-0.00480578  0.12464801 -0.00836801]
#  [-0.08550058 -0.00836801  0.29385585]]
#
# Predictive distribution ~ N(1.96004,3.31940)
# --------------------------------------------------
# Add data point (0.28634623366299095, 1.675911092428358):
#
# Posterior mean:
# [[1.27956851]
#  [1.38083279]
#  [2.26494928]]
#
# Posterior variance:
# [[ 0.06529548 -0.00537802 -0.08429165]
#  [-0.00537802  0.12435009 -0.00773861]
#  [-0.08429165 -0.00773861  0.29252617]]
#
# Predictive distribution ~ N(1.86446,3.06142)
# --------------------------------------------------
# Add data point (0.21908262326954842, 1.96556171935141):
#
# Posterior mean:
# [[1.28496015]
#  [1.38276191]
#  [2.25849181]]
#
# Posterior variance:
# [[ 0.06411671 -0.00579978 -0.08287987]
#  [-0.00579978  0.12419918 -0.00723347]
#  [-0.08287987 -0.00723347  0.2908353 ]]
#
# Predictive distribution ~ N(1.69080,3.06133)
# --------------------------------------------------
# Add data point (-0.5630867395025696, -1.5356679376975566):
#
# Posterior mean:
# [[1.24826264]
#  [1.45242512]
#  [2.24652175]]
#
# Posterior variance:
# [[ 0.06356981 -0.00476159 -0.08305826]
#  [-0.00476159  0.12222837 -0.00689484]
#  [-0.08305826 -0.00689484  0.29077711]]
#
# Predictive distribution ~ N(1.22244,3.08929)
# --------------------------------------------------
# Add data point (-0.3572416215194716, 0.8065370594533666):
#
# Posterior mean:
# [[1.24452674]
#  [1.45579445]
#  [2.24949332]]
#
# Posterior variance:
# [[ 0.06259519 -0.0038826  -0.08228303]
#  [-0.0038826   0.12143563 -0.00759399]
#  [-0.08228303 -0.00759399  0.29016049]]
#
# Predictive distribution ~ N(1.01610,3.06674)
# --------------------------------------------------
# Add data point (0.29927653332516924, 2.1219142193256193):
#
# Posterior mean:
# [[1.24877327]
#  [1.45829069]
#  [2.24489304]]
#
# Posterior variance:
# [[ 0.06163949 -0.00444439 -0.08124772]
#  [-0.00444439  0.12110539 -0.0069854 ]
#  [-0.08124772 -0.0069854   0.28903893]]
#
# Predictive distribution ~ N(1.88169,3.05833)
# --------------------------------------------------
# Add data point (-0.3978327865549842, -0.39459295937014083):
#
# Posterior mean:
# [[1.22539227]
#  [1.48314315]
#  [2.26002859]]
#
# Posterior variance:
# [[ 0.06080631 -0.00355877 -0.08070836]
#  [-0.00355877  0.12016404 -0.0075587 ]
#  [-0.08070836 -0.0075587   0.28868978]]
#
# Predictive distribution ~ N(1.02392,3.06674)
# --------------------------------------------------
# Add data point (-0.8719923437371282, -1.5592318987033833):
#
# Posterior mean:
# [[1.22285321]
#  [1.59713257]
#  [2.11476061]]
#
# Posterior variance:
# [[ 0.0608043  -0.00346853 -0.08082338]
#  [-0.00346853  0.11611242 -0.00239532]
#  [-0.08082338 -0.00239532  0.28210958]]
#
# Predictive distribution ~ N(1.65056,3.21258)
# --------------------------------------------------
# Add data point (-0.8593165276359651, 4.78949935513382):
#
# Posterior mean:
# [[1.22719722]
#  [1.48594585]
#  [2.25192656]]
#
# Posterior variance:
# [[ 0.06079902 -0.00333346 -0.08099   ]
#  [-0.00333346  0.11265536  0.0018695 ]
#  [-0.08099     0.0018695   0.27684826]]
#
# Predictive distribution ~ N(1.41200,3.19001)
# --------------------------------------------------
# Add data point (-0.5558996358997561, 0.4146100956949298):
#
# Posterior mean:
# [[1.21884724]
#  [1.50045587]
#  [2.25114456]]
#
# Posterior variance:
# [[ 0.06033868 -0.00253351 -0.08103311]
#  [-0.00253351  0.11126525  0.00194442]
#  [-0.08103311  0.00194442  0.27684423]]
#
# Predictive distribution ~ N(1.09706,3.07506)
# --------------------------------------------------
# Add data point (0.14735704362498825, 0.8086598524033795):
#
# Posterior mean:
# [[1.20590357]
#  [1.49736384]
#  [2.267764  ]]
#
# Posterior variance:
# [[ 0.05923102 -0.00279811 -0.0796109 ]
#  [-0.00279811  0.11120204  0.00228416]
#  [-0.0796109   0.00228416  0.27501813]]
#
# Predictive distribution ~ N(1.48883,3.05863)
# --------------------------------------------------
# Add data point (-0.2017219648231081, 1.666701431275994):
#
# Posterior mean:
# [[1.21830203]
#  [1.49185317]
#  [2.25266365]]
#
# Posterior variance:
# [[ 0.05818533 -0.00233334 -0.07833734]
#  [-0.00233334  0.11099547  0.00171811]
#  [-0.07833734  0.00171811  0.27346703]]
#
# Predictive distribution ~ N(0.99613,3.05882)
# --------------------------------------------------
# Add data point (0.6909230262686161, 5.501175528137987):
#
# Posterior mean:
# [[1.2317824 ]
#  [1.54469809]
#  [2.29019822]]
#
# Posterior variance:
# [[ 0.05806657 -0.00279889 -0.07866801]
#  [-0.00279889  0.10917042  0.00042182]
#  [-0.07866801  0.00042182  0.2725463 ]]
#
# Predictive distribution ~ N(3.32442,3.09661)
# --------------------------------------------------
# Add data point (-0.37375509513037053, 0.3324585639596879):
#
# Posterior mean:
# [[1.22168309]
#  [1.55383616]
#  [2.29875075]]
#
# Posterior variance:
# [[ 5.73094389e-02 -2.11382319e-03 -7.80268364e-02]
#  [-2.11382319e-03  1.08550556e-01 -1.58330400e-04]
#  [-7.80268364e-02 -1.58330400e-04  2.72003330e-01]]
#
# Predictive distribution ~ N(0.97437,3.05870)
# --------------------------------------------------
# Add data point (-0.03651884126132532, 1.9281612824937997):
#
# Posterior mean:
# [[1.23592517]
#  [1.55232495]
#  [2.27944269]]
#
# Posterior variance:
# [[ 0.05623621 -0.00199994 -0.07657185]
#  [-0.00199994  0.10853847 -0.00031272]
#  [-0.07657185 -0.00031272  0.2700308 ]]
#
# Predictive distribution ~ N(1.16800,3.05740)
# --------------------------------------------------
# Add data point (-0.011217880952528958, 0.17990259999204516):
#
# Posterior mean:
# [[1.21680489]
#  [1.55341867]
#  [2.30545841]]
#
# Posterior variance:
# [[ 0.05520098 -0.00194073 -0.07516328]
#  [-0.00194073  0.10853509 -0.00039329]
#  [-0.07516328 -0.00039329  0.26811425]]
#
# Predictive distribution ~ N(1.21880,3.05628)
# --------------------------------------------------
# Add data point (-0.055666988291228625, -0.013117309446879388):
#
# Posterior mean:
# [[1.19606377]
#  [1.55642527]
#  [2.33344303]]
#
# Posterior variance:
# [[ 0.05420815 -0.00179681 -0.07382372]
#  [-0.00179681  0.10851422 -0.00058747]
#  [-0.07382372 -0.00058747  0.26630687]]
#
# Predictive distribution ~ N(1.13747,3.05529)
# --------------------------------------------------
# Add data point (-0.43438935943649337, 3.2450663514788154):
#
# Posterior mean:
# [[1.22674112]
#  [1.51978071]
#  [2.31602074]]
#
# Posterior variance:
# [[ 0.05365687 -0.00113829 -0.07351064]
#  [-0.00113829  0.10772761 -0.00096146]
#  [-0.07351064 -0.00096146  0.26612907]]
#
# Predictive distribution ~ N(0.96028,3.05796)
# --------------------------------------------------
# Add data point (0.17969241740238773, -0.6960812682773965):
#
# Posterior mean:
# [[1.18874144]
#  [1.50624949]
#  [2.36444423]]
#
# Posterior variance:
# [[ 0.05280207 -0.00144267 -0.07242137]
#  [-0.00144267  0.10761923 -0.00057358]
#  [-0.07242137 -0.00057358  0.26474099]]
#
# Predictive distribution ~ N(1.57462,3.05225)
# --------------------------------------------------
# Add data point (0.47132795788638826, 3.7410872158180846):
#
# Posterior mean:
# [[1.20427149]
#  [1.52743416]
#  [2.35846235]]
#
# Posterior variance:
# [[ 0.05237721 -0.00202223 -0.07225772]
#  [-0.00202223  0.10682865 -0.00035034]
#  [-0.07225772 -0.00035034  0.26467796]]
#
# Predictive distribution ~ N(2.42394,3.05612)
# --------------------------------------------------
# Add data point (0.760067229002505, 0.10156693651674242):
#
# Posterior mean:
# [[1.19368394]
#  [1.43551956]
#  [2.26490818]]
#
# Posterior variance:
# [[ 0.05235065 -0.00225281 -0.07249241]
#  [-0.00225281  0.10482688 -0.00238782]
#  [-0.07249241 -0.00238782  0.26260414]]
#
# Predictive distribution ~ N(3.72771,3.11556)
# --------------------------------------------------
# Add data point (0.873105658142802, 3.156793608195531):
#
# Posterior mean:
# [[1.19525007]
#  [1.40744366]
#  [2.22458201]]
#
# Posterior variance:
# [[ 0.05234314 -0.00211812 -0.07229895]
#  [-0.00211812  0.10241221 -0.00585608]
#  [-0.07229895 -0.00585608  0.25762258]]
#
# Predictive distribution ~ N(4.17361,3.16723)
# --------------------------------------------------
# Add data point (0.5564216006798495, -0.20381507067753368):
#
# Posterior mean:
# [[1.16824429]
#  [1.35766188]
#  [2.22063739]]
#
# Posterior variance:
# [[ 0.05207241 -0.00261717 -0.07233849]
#  [-0.00261717  0.10149227 -0.00592898]
#  [-0.07233849 -0.00592898  0.2576168 ]]
#
# Predictive distribution ~ N(2.66712,3.05960)
# --------------------------------------------------
# Add data point (0.9928165364771102, 4.602280368628298):
#
# Posterior mean:
# [[1.16893572]
#  [1.35473823]
#  [2.215072  ]]
#
# Posterior variance:
# [[ 0.05192548 -0.00199587 -0.07115581]
#  [-0.00199587  0.09886518 -0.01092985]
#  [-0.07115581 -0.01092985  0.24809725]]
#
# Predictive distribution ~ N(4.70500,3.24300)
# --------------------------------------------------
# Add data point (-0.5208755813525074, 0.9760255091587476):
#
# Posterior mean:
# [[1.16796628]
#  [1.35636428]
#  [2.21501875]]
#
# Posterior variance:
# [[ 0.05155566 -0.00137557 -0.07117613]
#  [-0.00137557  0.09782473 -0.01089578]
#  [-0.07117613 -0.01089578  0.24809613]]
#
# Predictive distribution ~ N(1.06426,3.06357)
# --------------------------------------------------
# Add data point (0.7601615162054076, 5.038434889690512):
#
# Posterior mean:
# [[1.17269011]
#  [1.38994604]
#  [2.24719644]]
#
# Posterior variance:
# [[ 0.05152724 -0.00157758 -0.07136969]
#  [-0.00157758  0.09638861 -0.01227186]
#  [-0.07136969 -0.01227186  0.24677759]]
#
# Predictive distribution ~ N(3.47896,3.09700)
# --------------------------------------------------
# Add data point (-0.840033234352318, 2.5945959247581007):
#
# Posterior mean:
# [[1.17348133]
#  [1.36096451]
#  [2.28312798]]
#
# Posterior variance:
# [[ 0.05152528 -0.00150569 -0.07145883]
#  [-0.00150569  0.09375519 -0.00900693]
#  [-0.07145883 -0.00900693  0.2427297 ]]
#
# Predictive distribution ~ N(1.59084,3.15890)
# --------------------------------------------------
# Add data point (0.05134698011801664, 0.07722423691753422):
#
# Posterior mean:
# [[1.15378957]
#  [1.3597027 ]
#  [2.31051127]]
#
# Posterior variance:
# [[ 0.05066414 -0.00156087 -0.07026133]
#  [-0.00156087  0.09375166 -0.00893019]
#  [-0.07026133 -0.00893019  0.24106446]]
#
# Predictive distribution ~ N(1.24938,3.05124)
# --------------------------------------------------
# Add data point (-0.5956005674404177, 2.816036581684447):
#
# Posterior mean:
# [[1.16814436]
#  [1.32710223]
#  [2.32158458]]
#
# Posterior variance:
# [[ 0.05043247 -0.00103472 -0.07044005]
#  [-0.00103472  0.09255676 -0.00852432]
#  [-0.07044005 -0.00852432  0.2409266 ]]
#
# Predictive distribution ~ N(1.16358,3.07004)
# --------------------------------------------------
# Add data point (-0.3871060277090699, 1.233533626388512):
#
# Posterior mean:
# [[1.17119749]
#  [1.32421102]
#  [2.31923189]]
#
# Posterior variance:
# [[ 0.04990064 -0.0005311  -0.07003023]
#  [-0.0005311   0.09207984 -0.0089124 ]
#  [-0.07003023 -0.0089124   0.2406108 ]]
#
# Predictive distribution ~ N(1.00231,3.05039)
# --------------------------------------------------
# Add data point (-0.36574176283635706, -0.6527134404365714):
#
# Posterior mean:
# [[1.14916018]
#  [1.34336623]
#  [2.3379456 ]]
#
# Posterior variance:
# [[ 4.93566334e-02 -5.82437279e-05 -6.95682711e-02]
#  [-5.82437279e-05  9.16688274e-02 -9.31394817e-03]
#  [-6.95682711e-02 -9.31394817e-03  2.40218515e-01]]
#
# Predictive distribution ~ N(0.99711,3.04905)
# --------------------------------------------------
# Add data point (0.2172400014613569, -2.209845229310131):
#
# Posterior mean:
# [[1.09231147]
#  [1.3194024 ]
#  [2.41231282]]
#
# Posterior variance:
# [[ 0.04866044 -0.00035171 -0.06865754]
#  [-0.00035171  0.09154512 -0.00893004]
#  [-0.06865754 -0.00893004  0.23902713]]
#
# Predictive distribution ~ N(1.55133,3.04744)
# --------------------------------------------------
# Add data point (0.8293900274068153, 3.031164388564622):
#
# Posterior mean:
# [[1.09201368]
#  [1.30126605]
#  [2.38923235]]
#
# Posterior variance:
# [[ 0.04866002 -0.00037709 -0.06868983]
#  [-0.00037709  0.08999974 -0.0108967 ]
#  [-0.06868983 -0.0108967   0.23652435]]
#
# Predictive distribution ~ N(3.84601,3.11951)
# --------------------------------------------------
# Add data point (-0.9429345126093094, 1.2739238916235869):
#
# Posterior mean:
# [[1.094699  ]
#  [1.32240641]
#  [2.3554083 ]]
#
# Posterior variance:
# [[ 0.04861476 -0.00073341 -0.06811972]
#  [-0.00073341  0.08719457 -0.00640849]
#  [-0.06811972 -0.00640849  0.22934333]]
#
# Predictive distribution ~ N(1.98933,3.21250)
# --------------------------------------------------
# Add data point (-0.9340525792806031, 2.7778667054371944):
#
# Posterior mean:
# [[1.09195879]
#  [1.29866807]
#  [2.39272092]]
#
# Posterior variance:
# [[ 0.04858261 -0.00101198 -0.06768187]
#  [-0.00101198  0.0847814  -0.00261539]
#  [-0.06768187 -0.00261539  0.22338121]]
#
# Predictive distribution ~ N(1.91449,3.19221)
# --------------------------------------------------
# Add data point (0.11996163541367832, 2.5025474286053373):
#
# Posterior mean:
# [[1.11097401]
#  [1.30232034]
#  [2.36678078]]
#
# Posterior variance:
# [[ 0.04784268 -0.00115409 -0.06667248]
#  [-0.00115409  0.0847541  -0.00242152]
#  [-0.06667248 -0.00242152  0.22200423]]
#
# Predictive distribution ~ N(1.28218,3.04765)
# --------------------------------------------------
# Add data point (-0.0718194865316859, 2.800176499185993):
#
# Posterior mean:
# [[1.13861545]
#  [1.29810655]
#  [2.32881525]]
#
# Posterior variance:
# [[ 0.04709984 -0.00104085 -0.06565218]
#  [-0.00104085  0.08473684 -0.00257705]
#  [-0.06565218 -0.00257705  0.22060285]]
#
# Predictive distribution ~ N(1.02965,3.04777)
# --------------------------------------------------
# Add data point (0.8677918396013113, 7.439122949385414):
#
# Posterior mean:
# [[1.13507324]
#  [1.37515372]
#  [2.436098  ]]
#
# Posterior variance:
# [[ 0.04709648 -0.00096778 -0.06555044]
#  [-0.00096778  0.08314753 -0.00479005]
#  [-0.06555044 -0.00479005  0.21752141]]
#
# Predictive distribution ~ N(4.01885,3.13196)
# --------------------------------------------------
# Add data point (0.32367079501099494, 3.40142256420828):
#
# Posterior mean:
# [[1.15561204]
#  [1.38824535]
#  [2.41329687]]
#
# Posterior variance:
# [[ 0.04657297 -0.00130147 -0.06496927]
#  [-0.00130147  0.08293484 -0.00441961]
#  [-0.06496927 -0.00441961  0.21687623]]
#
# Predictive distribution ~ N(1.83538,3.04351)
# --------------------------------------------------
# Add data point (-0.9447993003403021, 3.6439847988699494):
#
# Posterior mean:
# [[1.15034948]
#  [1.34507716]
#  [2.48186749]]
#
# Posterior variance:
# [[ 0.04654038 -0.0015688  -0.06454463]
#  [-0.0015688   0.08074193 -0.00093629]
#  [-0.06454463 -0.00093629  0.21134314]]
#
# Predictive distribution ~ N(1.99822,3.18734)
# --------------------------------------------------
# Add data point (0.1531273421950139, 2.274101456313222):
#
# Posterior mean:
# [[1.16299241]
#  [1.3481183 ]
#  [2.4650055 ]]
#
# Posterior variance:
# [[ 0.04588166 -0.00172725 -0.06366608]
#  [-0.00172725  0.08070382 -0.00072496]
#  [-0.06366608 -0.00072496  0.21017141]]
#
# Predictive distribution ~ N(1.41451,3.04504)
# --------------------------------------------------
# Add data point (0.9677063807364652, 5.079327607382157):
#
# Posterior mean:
# [[1.16152308]
#  [1.35533532]
#  [2.47763418]]
#
# Posterior variance:
# [[ 0.04580702 -0.00136067 -0.06302461]
#  [-0.00136067  0.07890324 -0.00387569]
#  [-0.06302461 -0.00387569  0.2046581 ]]
#
# Predictive distribution ~ N(4.77594,3.18187)
# --------------------------------------------------
# Add data point (0.3941587957924515, 1.5691555208007677):
#
# Posterior mean:
# [[1.15555701]
#  [1.35043562]
#  [2.48314239]]
#
# Posterior variance:
# [[ 0.04539321 -0.00170052 -0.06264255]
#  [-0.00170052  0.07862414 -0.00356193]
#  [-0.06264255 -0.00356193  0.20430536]]
#
# Predictive distribution ~ N(2.08067,3.04187)
# --------------------------------------------------
# Add data point (0.35236445044590425, 2.0510879217573206):
#
# Posterior mean:
# [[1.15691262]
#  [1.35137174]
#  [2.48173131]]
#
# Posterior variance:
# [[ 0.04494267 -0.00201164 -0.06217358]
#  [-0.00201164  0.0784093  -0.00323807]
#  [-0.06217358 -0.00323807  0.20381719]]
#
# Predictive distribution ~ N(1.93971,3.04124)
# --------------------------------------------------
# Add data point (0.002086186341338392, -1.4561864396154056):
#
# Posterior mean:
# [[1.11830583]
#  [1.35295944]
#  [2.5351502 ]]
#
# Posterior variance:
# [[ 0.04427945 -0.00198436 -0.06125591]
#  [-0.00198436  0.07840817 -0.00327581]
#  [-0.06125591 -0.00327581  0.20254745]]
#
# Predictive distribution ~ N(1.15974,3.04493)
# --------------------------------------------------
# Add data point (0.24215678513274197, 1.8768987071822347):
#
# Posterior mean:
# [[1.12203792]
#  [1.35451984]
#  [2.53049314]]
#
# Posterior variance:
# [[ 0.04374791 -0.0022066  -0.06059263]
#  [-0.0022066   0.07831526 -0.00299849]
#  [-0.06059263 -0.00299849  0.20171979]]
#
# Predictive distribution ~ N(1.59460,3.04134)
# --------------------------------------------------
# Add data point (-0.9195801752531636, 1.6370236838436076):
#
# Posterior mean:
# [[1.12269337]
#  [1.36373154]
#  [2.51696294]]
#
# Posterior variance:
# [[ 0.04373847 -0.00233925 -0.06039779]
#  [-0.00233925  0.07645097 -0.00026023]
#  [-0.06039779 -0.00026023  0.1976978 ]]
#
# Predictive distribution ~ N(2.01630,3.16046)
# --------------------------------------------------
# Add data point (0.28836014442770774, -0.08209619526523793):
#
# Posterior mean:
# [[1.10007741]
#  [1.35202902]
#  [2.54314128]]
#
# Posterior variance:
# [[ 4.32624392e-02 -2.58557536e-03 -5.98467737e-02]
#  [-2.58557536e-03  7.63235141e-02  2.48966519e-05]
#  [-5.98467737e-02  2.48966519e-05  1.97059989e-01]]
#
# Predictive distribution ~ N(1.72523,3.04006)
# --------------------------------------------------
# Add data point (0.7423638233254908, 1.477729137375979):
#
# Posterior mean:
# [[1.09456494]
#  [1.31636927]
#  [2.51098613]]
#
# Posterior variance:
# [[ 0.04323971 -0.00273263 -0.05997937]
#  [-0.00273263  0.07537225 -0.00083288]
#  [-0.05997937 -0.00083288  0.19628652]]
#
# Predictive distribution ~ N(3.50531,3.07539)
# --------------------------------------------------
# Add data point (-0.03712968828967922, 0.7912363394984465):
#
# Posterior mean:
# [[1.09089896]
#  [1.31683812]
#  [2.51604358]]
#
# Posterior variance:
# [[ 0.04262483 -0.00265399 -0.05913111]
#  [-0.00265399  0.07536219 -0.00094136]
#  [-0.05913111 -0.00094136  0.19511629]]
#
# Predictive distribution ~ N(1.04915,3.04338)
# --------------------------------------------------
# Add data point (-0.3942951520127276, 2.9789560544857077):
#
# Posterior mean:
# [[1.11374314]
#  [1.29529453]
#  [2.49720978]]
#
# Posterior variance:
# [[ 0.04223417 -0.00228557 -0.05880903]
#  [-0.00228557  0.07501475 -0.00124511]
#  [-0.05880903 -0.00124511  0.19485075]]
#
# Predictive distribution ~ N(0.96284,3.04288)
# --------------------------------------------------
# Add data point (0.37727146084235064, 3.4794801799180606):
#
# Posterior mean:
# [[1.1302709 ]
#  [1.3082348 ]
#  [2.48141143]]
#
# Posterior variance:
# [[ 0.04187571 -0.00256622 -0.05846639]
#  [-0.00256622  0.07479501 -0.00097684]
#  [-0.05846639 -0.00097684  0.19452323]]
#
# Predictive distribution ~ N(1.95786,3.03826)
# --------------------------------------------------
# Add data point (0.6002173646093605, 3.3934187590819094):
#
# Posterior mean:
# [[1.13396275]
#  [1.31627566]
#  [2.48352368]]
#
# Posterior variance:
# [[ 0.04175387 -0.00283159 -0.0585361 ]
#  [-0.00283159  0.07421704 -0.00112867]
#  [-0.0585361  -0.00112867  0.19448335]]
#
# Predictive distribution ~ N(2.80945,3.04844)
# --------------------------------------------------
# Add data point (-0.047224572191768566, 0.3359223777102761):
#
# Posterior mean:
# [[1.12378517]
#  [1.31782068]
#  [2.49767216]]
#
# Posterior variance:
# [[ 0.04118066 -0.00274457 -0.05773925]
#  [-0.00274457  0.07420383 -0.00124963]
#  [-0.05773925 -0.00124963  0.1933756 ]]
#
# Predictive distribution ~ N(1.07734,3.04193)
# --------------------------------------------------
# Add data point (-0.5900782459845706, 1.0320510885884289):
#
# Posterior mean:
# [[1.12241936]
#  [1.32064703]
#  [2.49705051]]
#
# Posterior variance:
# [[ 0.041012   -0.00239554 -0.05781602]
#  [-0.00239554  0.07348157 -0.00109077]
#  [-0.05781602 -0.00109077  0.19334066]]
#
# Predictive distribution ~ N(1.21584,3.05401)
# --------------------------------------------------
# Add data point (0.9012368202410528, 5.509818837336565):
#
# Posterior mean:
# [[1.11939008]
#  [1.3441672 ]
#  [2.53375947]]
#
# Posterior variance:
# [[ 0.04099099 -0.00223244 -0.05756145]
#  [-0.00223244  0.07221518 -0.00306729]
#  [-0.05756145 -0.00306729  0.19025582]]
#
# Predictive distribution ~ N(4.34081,3.12841)
# --------------------------------------------------
# Add data point (0.4672383404419902, 2.1522596947463715):
#
# Posterior mean:
# [[1.1180532 ]
#  [1.34266149]
#  [2.53461192]]
#
# Posterior variance:
# [[ 0.0407442  -0.0025104  -0.05740409]
#  [-0.0025104   0.07190212 -0.00289005]
#  [-0.05740409 -0.00289005  0.19015548]]
#
# Predictive distribution ~ N(2.30059,3.03798)
# --------------------------------------------------
# Add data point (-0.6371684945600802, 2.4457084674049288):
#
# Posterior mean:
# [[1.12523553]
#  [1.32398854]
#  [2.54277463]]
#
# Posterior variance:
# [[ 0.04062572 -0.00220237 -0.05753874]
#  [-0.00220237  0.07110129 -0.00253998]
#  [-0.05753874 -0.00253998  0.19000245]]
#
# Predictive distribution ~ N(1.29156,3.05936)
# --------------------------------------------------
# Add data point (0.4838940235029767, 5.682586065191685):
#
# Posterior mean:
# [[1.15375479]
#  [1.35854382]
#  [2.52716536]]
#
# Posterior variance:
# [[ 0.04040172 -0.00247379 -0.05741614]
#  [-0.00247379  0.07077243 -0.00239143]
#  [-0.05741614 -0.00239143  0.18993535]]
#
# Predictive distribution ~ N(2.36131,3.03804)
# --------------------------------------------------
# Add data point (-0.20591957110323889, 1.9936274677012635):
#
# Posterior mean:
# [[1.16656957]
#  [1.35283239]
#  [2.51088902]]
#
# Posterior variance:
# [[ 0.03991472 -0.00225674 -0.05679759]
#  [-0.00225674  0.0706757  -0.00266711]
#  [-0.05679759 -0.00266711  0.18914972]]
#
# Predictive distribution ~ N(0.98116,3.03994)
# --------------------------------------------------
# Add data point (0.8472953517624557, 2.5189685972522544):
#
# Posterior mean:
# [[1.1679978 ]
#  [1.32413749]
#  [2.47136588]]
#
# Posterior variance:
# [[ 0.03991224 -0.0022069  -0.05672894]
#  [-0.0022069   0.06967432 -0.00404636]
#  [-0.05672894 -0.00404636  0.18724999]]
#
# Predictive distribution ~ N(4.11541,3.09952)
# --------------------------------------------------
# Add data point (-0.6127970740927857, -2.366802531076029):
#
# Posterior mean:
# [[1.14413461]
#  [1.3796332 ]
#  [2.45215886]]
#
# Posterior variance:
# [[ 0.03978178 -0.00190351 -0.05683394]
#  [-0.00190351  0.06896877 -0.00380217]
#  [-0.05683394 -0.00380217  0.18716547]]
#
# Predictive distribution ~ N(1.28462,3.05444)
# --------------------------------------------------
# Add data point (-0.7475500268307229, 0.6508679808560155):
#
# Posterior mean:
# [[1.14158204]
#  [1.39465691]
#  [2.43848213]]
#
# Posterior variance:
# [[ 0.03975282 -0.00173303 -0.05698914]
#  [-0.00173303  0.06796535 -0.00288872]
#  [-0.05698914 -0.00288872  0.18633392]]
#
# Predictive distribution ~ N(1.48313,3.07928)
# --------------------------------------------------
# Add data point (0.5901473885196769, 4.4588653432788234):
#
# Posterior mean:
# [[1.15178899]
#  [1.41485783]
#  [2.44183431]]
#
# Posterior variance:
# [[ 0.03963565 -0.00196491 -0.05702762]
#  [-0.00196491  0.06750643 -0.00296488]
#  [-0.05702762 -0.00296488  0.18632128]]
#
# Predictive distribution ~ N(2.81389,3.04310)
# --------------------------------------------------
# Add data point (-0.1603358342816592, -0.5192866394562529):
#
# Posterior mean:
# [[1.13270636]
#  [1.42123686]
#  [2.4675007 ]]
#
# Posterior variance:
# [[ 0.03914833 -0.00180201 -0.05637217]
#  [-0.00180201  0.06745197 -0.00318398]
#  [-0.05637217 -0.00318398  0.18543969]]
#
# Predictive distribution ~ N(0.98771,3.03922)
# --------------------------------------------------
# Add data point (0.08991549832535362, -0.698406873663068):
#
# Posterior mean:
# [[1.10761267]
#  [1.41847729]
#  [2.50342411]]
#
# Posterior variance:
# [[ 0.03865973 -0.00185574 -0.0556727 ]
#  [-0.00185574  0.06744606 -0.00310706]
#  [-0.0556727  -0.00310706  0.18443835]]
#
# Predictive distribution ~ N(1.28045,3.03847)
# --------------------------------------------------
# Add data point (0.1688399587934768, 1.6304333158796438):
#
# Posterior mean:
# [[1.11017828]
#  [1.41913638]
# ...
#  [-1.16013659e-02 -9.94332431e-05  3.52065213e-02]]
#
# Predictive distribution ~ N(0.75114,3.00602)
# --------------------------------------------------
# Add data point (-0.16443991720101447, -1.3439638361912873):
#
# Posterior mean:
# [[1.06093142]
#  [1.88602844]
#  [2.79445837]]
#
# Posterior variance:
# [[ 0.00692609 -0.00011969 -0.01157786]
#  [-0.00011969  0.00937117 -0.00010533]
#  [-0.01157786 -0.00010533  0.03516892]]
#
# Predictive distribution ~ N(0.83116,3.00663)
# --------------------------------------------------
# Add data point (0.4507835644799234, 4.086970625890803):
#
# Posterior mean:
# [[1.06334944]
#  [1.8882131 ]
#  [2.79206208]]
#
# Posterior variance:
# [[ 6.91929294e-03 -1.25835075e-04 -1.15711223e-02]
#  [-1.25835075e-04  9.36562117e-03 -9.92443723e-05]
#  [-1.15711223e-02 -9.92443723e-05  3.51622430e-02]]
#
# Predictive distribution ~ N(2.47897,3.00545)
# --------------------------------------------------
# Add data point (-0.5473836411987791, 1.3639507384786476):
#
# Posterior mean:
# [[1.06393229]
#  [1.88733876]
#  [2.79189967]]
#
# Posterior variance:
# [[ 0.00691517 -0.00011965 -0.01156997]
#  [-0.00011965  0.00935634 -0.00010097]
#  [-0.01156997 -0.00010097  0.03516192]]
#
# Predictive distribution ~ N(0.86635,3.00612)
# --------------------------------------------------
# Add data point (-0.33586489533354547, 1.0399519640756145):
#
# Posterior mean:
# [[1.06448675]
#  [1.88701753]
#  [2.79115686]]
#
# Posterior variance:
# [[ 0.00690455 -0.00011349 -0.01155574]
#  [-0.00011349  0.00935277 -0.00010921]
#  [-0.01155574 -0.00010921  0.03514286]]
#
# Predictive distribution ~ N(0.74498,3.00590)
# --------------------------------------------------
# Add data point (0.37914309398000423, 3.021036766200748):
#
# Posterior mean:
# [[1.06593994]
#  [1.88797233]
#  [2.78932782]]
#
# Posterior variance:
# [[ 0.00689555 -0.00011941 -0.01154442]
#  [-0.00011941  0.00934889 -0.00010177]
#  [-0.01154442 -0.00010177  0.03512861]]
#
# Predictive distribution ~ N(2.18116,3.00555)
# --------------------------------------------------
# Add data point (-0.6743834914317648, 0.4119618899142159):
#
# Posterior mean:
# [[1.06556743]
#  [1.88936902]
#  [2.78835636]]
#
# Posterior variance:
# [[ 6.89455978e-03 -1.15694713e-04 -1.15470011e-02]
#  [-1.15694713e-04  9.33497261e-03 -9.20904874e-05]
#  [-1.15470011e-02 -9.20904874e-05  3.51218731e-02]]
#
# Predictive distribution ~ N(1.06129,3.00814)
# --------------------------------------------------
# Add data point (-0.38177002419178585, 2.9048366678560043):
#
# Posterior mean:
# [[1.06933418]
#  [1.88672234]
#  [2.78377465]]
#
# Posterior variance:
# [[ 6.88536963e-03 -1.09237323e-04 -1.15358226e-02]
#  [-1.09237323e-04  9.33043537e-03 -9.99449708e-05]
#  [-1.15358226e-02 -9.99449708e-05  3.51082761e-02]]
#
# Predictive distribution ~ N(0.75066,3.00573)
# --------------------------------------------------
# Add data point (-0.8319507201879772, -0.4780869832336676):
#
# Posterior mean:
# [[1.06997114]
#  [1.89173932]
#  [2.77565788]]
#
# Posterior variance:
# [[ 6.88503245e-03 -1.11893100e-04 -1.15315259e-02]
#  [-1.11893100e-04  9.30951724e-03 -6.61023244e-05]
#  [-1.15315259e-02 -6.61023244e-05  3.50535233e-02]]
#
# Predictive distribution ~ N(1.42644,3.01449)
# --------------------------------------------------
# Add data point (0.2626993517365972, 1.209746392506766):
#
# Posterior mean:
# [[1.06886495]
#  [1.89131414]
#  [2.77732447]]
#
# Posterior variance:
# [[ 6.87281651e-03 -1.16588399e-04 -1.15131213e-02]
#  [-1.16588399e-04  9.30771256e-03 -5.90283374e-05]
#  [-1.15131213e-02 -5.90283374e-05  3.50257947e-02]]
#
# Predictive distribution ~ N(1.75848,3.00604)
# --------------------------------------------------
# Add data point (-0.5981165100488184, -0.37073331615203253):
#
# Posterior mean:
# [[1.06764217]
#  [1.89378447]
#  [2.77686874]]
#
# Posterior variance:
# [[ 6.87016440e-03 -1.11230455e-04 -1.15141097e-02]
#  [-1.11230455e-04  9.29688816e-03 -5.70314373e-05]
#  [-1.15141097e-02 -5.70314373e-05  3.50254263e-02]]
#
# Predictive distribution ~ N(0.93121,3.00661)
# --------------------------------------------------
# Add data point (-0.4395672296609383, 0.8044852641246891):
#
# Posterior mean:
# [[1.06769331]
#  [1.89373862]
#  [2.7768173 ]]
#
# Posterior variance:
# [[ 6.86283265e-03 -1.04656903e-04 -1.15067356e-02]
#  [-1.04656903e-04  9.29099440e-03 -6.36429956e-05]
#  [-1.15067356e-02 -6.36429956e-05  3.50180095e-02]]
#
# Predictive distribution ~ N(0.77174,3.00563)
# --------------------------------------------------
# Add data point (0.35279324718891214, 2.678091249276815):
#
# Posterior mean:
# [[1.0687641 ]
#  [1.89436699]
#  [2.77539374]]
#
# Posterior variance:
# [[ 6.85315327e-03 -1.10337068e-04 -1.14938673e-02]
#  [-1.10337068e-04  9.28766110e-03 -5.60914764e-05]
#  [-1.14938673e-02 -5.60914764e-05  3.50009017e-02]]
#
# Predictive distribution ~ N(2.08140,3.00562)
# --------------------------------------------------
# Add data point (0.4448095862641124, -0.4058648289696305):
#
# Posterior mean:
# [[1.06444369]
#  [1.89054266]
#  [2.77977495]]
#
# Posterior variance:
# [[ 6.84632543e-03 -1.16380918e-04 -1.14869434e-02]
#  [-1.16380918e-04  9.28231122e-03 -4.99625779e-05]
#  [-1.14869434e-02 -4.99625779e-05  3.49938804e-02]]
#
# Predictive distribution ~ N(2.46052,3.00540)
# --------------------------------------------------
# Add data point (-0.16614553823642875, 0.6583758077582421):
#
# Posterior mean:
# [[1.06407625]
#  [1.8906358 ]
#  [2.78036481]]
#
# Posterior variance:
# [[ 6.83206190e-03 -1.12765305e-04 -1.14640456e-02]
#  [-1.12765305e-04  9.28139471e-03 -5.57668520e-05]
#  [-1.14640456e-02 -5.57668520e-05  3.49571218e-02]]
#
# Predictive distribution ~ N(0.82707,3.00653)
# --------------------------------------------------
# Add data point (-0.649071129683475, 0.8889499510103159):
#
# Posterior mean:
# [[1.0639939 ]
#  [1.89088022]
#  [2.78023391]]
#
# Posterior variance:
# [[ 6.83062952e-03 -1.08513754e-04 -1.14663226e-02]
#  [-1.08513754e-04  9.26877534e-03 -4.90083960e-05]
#  [-1.14663226e-02 -4.90083960e-05  3.49535022e-02]]
#
# Predictive distribution ~ N(1.00827,3.00746)
# --------------------------------------------------
# Add data point (-0.8450865400215195, 1.7674740508214426):
#
# Posterior mean:
# [[1.06386121]
#  [1.89004458]
#  [2.78165218]]
#
# Posterior variance:
# [[ 6.83009746e-03 -1.11864451e-04 -1.14606357e-02]
#  [-1.11864451e-04  9.24767403e-03 -1.31945088e-05]
#  [-1.14606357e-02 -1.31945088e-05  3.48927176e-02]]
#
# Predictive distribution ~ N(1.45160,3.01514)
# --------------------------------------------------
# Add data point (0.8982242238136691, 7.454806469265161):
#
# Posterior mean:
# [[1.06181903]
#  [1.89668497]
#  [2.79518548]]
#
# Posterior variance:
# [[ 6.82799866e-03 -1.05039977e-04 -1.14467272e-02]
#  [-1.05039977e-04  9.22548351e-03 -5.84194711e-05]
#  [-1.14467272e-02 -5.84194711e-05  3.48005477e-02]]
#
# Predictive distribution ~ N(5.00580,3.01829)
# --------------------------------------------------
# Add data point (0.12706073582009347, 3.754882262118835):
#
# Posterior mean:
# [[1.06712659]
#  [1.89753853]
#  [2.78646557]]
#
# Posterior variance:
# [[ 6.81337913e-03 -1.07391092e-04 -1.14227084e-02]
#  [-1.07391092e-04  9.22510540e-03 -5.45567774e-05]
#  [-1.14227084e-02 -5.45567774e-05  3.47610869e-02]]
#
# Predictive distribution ~ N(1.34794,3.00659)
# --------------------------------------------------
# Add data point (-0.731631152963022, 0.23274309451073372):
#
# Posterior mean:
# [[1.06688435]
#  [1.89968378]
#  [2.78421493]]
#
# Posterior variance:
# [[ 6.81317825e-03 -1.05612094e-04 -1.14245748e-02]
#  [-1.05612094e-04  9.20935073e-03 -3.80281011e-05]
#  [-1.14245748e-02 -3.80281011e-05  3.47437462e-02]]
#
# Predictive distribution ~ N(1.17038,3.00968)
# --------------------------------------------------
# Add data point (0.8544402955113244, 4.6642817707119715):
#
# Posterior mean:
# [[1.06691571]
#  [1.89953386]
#  [2.78394538]]
#
# Posterior variance:
# [[ 6.81231023e-03 -1.01461621e-04 -1.14171124e-02]
#  [-1.01461621e-04  9.18950511e-03 -7.37101864e-05]
#  [-1.14171124e-02 -7.37101864e-05  3.46795904e-02]]
#
# Predictive distribution ~ N(4.72272,3.01515)
# --------------------------------------------------
# Add data point (0.4992266083750805, 0.5730115745215931):
#
# Posterior mean:
# [[1.06413237]
#  [1.89635849]
#  [2.78594308]]
#
# Posterior variance:
# [[ 6.80720728e-03 -1.07283340e-04 -1.14134498e-02]
#  [-1.07283340e-04  9.18286339e-03 -6.95317093e-05]
#  [-1.14134498e-02 -6.95317093e-05  3.46769616e-02]]
#
# Predictive distribution ~ N(2.70905,3.00545)
# --------------------------------------------------
# Add data point (0.3660347871657821, 3.885431760157889):
#
# Posterior mean:
# [[1.0671895 ]
#  [1.89825194]
#  [2.78197905]]
#
# Posterior variance:
# [[ 6.79807591e-03 -1.12938904e-04 -1.14016096e-02]
#  [-1.12938904e-04  9.17936058e-03 -6.21984117e-05]
#  [-1.14016096e-02 -6.21984117e-05  3.46616090e-02]]
#
# Predictive distribution ~ N(2.13153,3.00552)
# --------------------------------------------------
# Add data point (-0.9439635420085108, 3.562632244344563):
#
# Posterior mean:
# [[1.06524205]
#  [1.89296685]
#  [2.7936718 ]]
#
# Posterior variance:
# [[ 6.79457071e-03 -1.22451492e-04 -1.13805639e-02]
#  [-1.22451492e-04  9.15354486e-03 -5.08360068e-06]
#  [-1.13805639e-02 -5.08360068e-06  3.45352480e-02]]
#
# Predictive distribution ~ N(1.75424,3.02250)
# --------------------------------------------------
# Add data point (-0.8079412047907177, 1.0924092553571496):
#
# Posterior mean:
# [[1.06528951]
#  [1.89363352]
#  [2.79268198]]
#
# Posterior variance:
# [[ 6.79447557e-03 -1.23788013e-04 -1.13785795e-02]
#  [-1.23788013e-04  9.13476853e-03  2.27941440e-05]
#  [-1.13785795e-02  2.27941440e-05  3.44938571e-02]]
#
# Predictive distribution ~ N(1.35946,3.01283)
# --------------------------------------------------
# Add data point (-0.6830330796919828, -0.4691283332225231):
#
# Posterior mean:
# [[1.06448344]
#  [1.89689389]
#  [2.79027055]]
#
# Posterior variance:
# [[ 6.79365560e-03 -1.20471370e-04 -1.13810326e-02]
#  [-1.20471370e-04  9.12135333e-03  3.27162476e-05]
#  [-1.13810326e-02  3.27162476e-05  3.44865185e-02]]
#
# Predictive distribution ~ N(1.07476,3.00810)
# --------------------------------------------------
# Add data point (0.7412359398816031, 2.09465666354843):
#
# Posterior mean:
# [[1.06419721]
#  [1.89267042]
#  [2.78545555]]
#
# Posterior variance:
# [[ 6.79358793e-03 -1.21469792e-04 -1.13821708e-02]
#  [-1.21469792e-04  9.10662137e-03  1.59209530e-05]
#  [-1.13821708e-02  1.59209530e-05  3.44673709e-02]]
#
# Predictive distribution ~ N(4.00359,3.00956)
# --------------------------------------------------
# Add data point (0.9122418194720034, 2.9414098690111032):
#
# Posterior mean:
# [[1.06619961]
#  [1.8867843 ]
#  [2.7730249 ]]
#
# Posterior variance:
# [[ 6.79101095e-03 -1.13894672e-04 -1.13661732e-02]
#  [-1.13894672e-04  9.08435407e-03 -3.11044195e-05]
#  [-1.13661732e-02 -3.11044195e-05  3.43680600e-02]]
#
# Predictive distribution ~ N(5.10879,3.01910)
# --------------------------------------------------
# Add data point (-0.38630087075614683, -0.5188910041204599):
#
# Posterior mean:
# [[1.06402816]
#  [1.88831726]
#  [2.77565551]]
#
# Posterior variance:
# [[ 6.78222478e-03 -1.07691978e-04 -1.13555292e-02]
#  [-1.07691978e-04  9.07997521e-03 -3.86186786e-05]
#  [-1.13555292e-02 -3.86186786e-05  3.43551653e-02]]
#
# Predictive distribution ~ N(0.75115,3.00561)
# --------------------------------------------------
# Add data point (0.19712158736890184, 4.791116852878529):
#
# Posterior mean:
# [[1.07085401]
#  [1.89013252]
#  [2.76482423]]
#
# Posterior variance:
# [[ 6.76893940e-03 -1.11225072e-04 -1.13344480e-02]
#  [-1.11225072e-04  9.07903563e-03 -3.30123564e-05]
#  [-1.13344480e-02 -3.30123564e-05  3.43217135e-02]]
#
# Predictive distribution ~ N(1.54411,3.00626)
# --------------------------------------------------
# Add data point (0.8275141428842256, 2.2939432688693104):
#
# Posterior mean:
# [[1.07165829]
#  [1.88466102]
#  [2.75582193]]
#
# Posterior variance:
# [[ 6.76854895e-03 -1.08568806e-04 -1.13300776e-02]
#  [-1.08568806e-04  9.06096509e-03 -6.27439229e-05]
#  [-1.13300776e-02 -6.27439229e-05  3.42727959e-02]]
#
# Predictive distribution ~ N(4.52826,3.01334)
# --------------------------------------------------
# Add data point (0.22302039612676228, 2.68272022427439):
#
# Posterior mean:
# [[1.07382471]
#  [1.88533017]
#  [2.75244323]]
#
# Posterior variance:
# [[ 6.75584081e-03 -1.12494024e-04 -1.13102583e-02]
#  [-1.12494024e-04  9.05975269e-03 -5.66222589e-05]
#  [-1.13102583e-02 -5.66222589e-05  3.42418864e-02]]
#
# Predictive distribution ~ N(1.62905,3.00613)
# --------------------------------------------------
# Add data point (-0.2815015498843476, 2.8461977200435404):
#
# Posterior mean:
# [[1.07791098]
#  [1.88348008]
#  [2.74649139]]
#
# Posterior variance:
# [[ 6.74429482e-03 -1.07266475e-04 -1.12934410e-02]
#  [-1.07266475e-04  9.05738587e-03 -6.42364356e-05]
#  [-1.12934410e-02 -6.42364356e-05  3.42173912e-02]]
#
# Predictive distribution ~ N(0.76121,3.00596)
# --------------------------------------------------
# Add data point (0.23679339906894814, 1.6928594796177188):
#
# Posterior mean:
# [[1.07794125]
#  [1.8834902 ]
#  [2.74644467]]
#
# Posterior variance:
# [[ 6.73197455e-03 -1.11383978e-04 -1.12744311e-02]
#  [-1.11383978e-04  9.05600978e-03 -5.78832135e-05]
#  [-1.12744311e-02 -5.78832135e-05  3.41880593e-02]]
#
# Predictive distribution ~ N(1.67791,3.00604)
# --------------------------------------------------
# Add data point (0.3355240311403618, 6.6539030906086705):
#
# Posterior mean:
# [[1.0863076 ]
#  [1.887994  ]
#  [2.73496377]]
#
# Posterior variance:
# [[ 6.72218118e-03 -1.16655987e-04 -1.12609919e-02]
#  [-1.16655987e-04  9.05317173e-03 -5.06485795e-05]
#  [-1.12609919e-02 -5.06485795e-05  3.41696171e-02]]
#
# Predictive distribution ~ N(2.01908,3.00557)
# --------------------------------------------------
# Add data point (-0.869575459735606, 3.5943190413627883):
#
# Posterior mean:
# [[1.08514023]
#  [1.88245402]
#  [2.74505412]]
#
# Posterior variance:
# [[ 6.72123262e-03 -1.21157577e-04 -1.12527929e-02]
#  [-1.21157577e-04  9.03180856e-03 -1.17383798e-05]
#  [-1.12527929e-02 -1.17383798e-05  3.40987472e-02]]
#
# Predictive distribution ~ N(1.51263,3.01634)
# --------------------------------------------------
# Add data point (-0.729756894996979, 3.7230727094241214):
#
# Posterior mean:
# [[1.08583248]
#  [1.87676164]
#  [2.75091296]]
#
# Posterior variance:
# [[ 6.72101080e-03 -1.19333577e-04 -1.12546702e-02]
#  [-1.19333577e-04  9.01680979e-03  3.69899128e-06]
#  [-1.12546702e-02  3.69899128e-06  3.40828584e-02]]
#
# Predictive distribution ~ N(1.17327,3.00940)
# --------------------------------------------------
# Add data point (0.03232510538714606, 2.293942202189896):
#
# Posterior mean:
# [[1.08838504]
#  [1.87682717]
#  [2.74664222]]
#
# Posterior variance:
# [[ 6.70605676e-03 -1.19717474e-04 -1.12296503e-02]
#  [-1.19717474e-04  9.01679993e-03  4.34129813e-06]
#  [-1.12296503e-02  4.34129813e-06  3.40409971e-02]]
#
# Predictive distribution ~ N(1.14937,3.00670)
# --------------------------------------------------
# Add data point (-0.13656700505204822, 2.227557459916218):
#
# Posterior mean:
# [[1.0912971 ]
#  [1.8762231 ]
#  [2.74190484]]
#
# Posterior variance:
# [[ 6.69194775e-03 -1.16790736e-04 -1.12066976e-02]
#  [-1.16790736e-04  9.01619282e-03 -4.19949435e-07]
#  [-1.12066976e-02 -4.19949436e-07  3.40036574e-02]]
#
# Predictive distribution ~ N(0.88330,3.00650)
# --------------------------------------------------
# Add data point (0.903110438724009, 5.076485797942364):
#
# Posterior mean:
# [[1.09125104]
#  [1.87636783]
#  [2.74220289]]
#
# Posterior variance:
# [[ 6.68978687e-03 -1.10000032e-04 -1.11927138e-02]
#  [-1.10000032e-04  8.99485262e-03 -4.43650483e-05]
#  [-1.11927138e-02 -4.43650483e-05  3.39131629e-02]]
#
# Predictive distribution ~ N(5.02205,3.01817)
# --------------------------------------------------
# Add data point (-0.9909614340532296, 5.641588494072719):
#
# Posterior mean:
# [[1.08610225]
#  [1.86523254]
#  [2.76941028]]
#
# Posterior variance:
# [[ 6.68397924e-03 -1.22560191e-04 -1.11620249e-02]
#  [-1.22560191e-04  8.96768879e-03  2.20056581e-05]
#  [-1.11620249e-02  2.20056581e-05  3.37509961e-02]]
#
# Predictive distribution ~ N(1.92470,3.02655)
# --------------------------------------------------
# Add data point (0.867989767924475, 3.1968286487090327):
#
# Posterior mean:
# [[1.08707105]
#  [1.86117217]
#  [2.76185565]]
#
# Posterior variance:
# [[ 6.68286635e-03 -1.17895963e-04 -1.11533468e-02]
#  [-1.17895963e-04  8.94814046e-03 -1.43655168e-05]
#  [-1.11533468e-02 -1.43655168e-05  3.36833247e-02]]
#
# Predictive distribution ~ N(4.79160,3.01560)
# --------------------------------------------------

# %%
import matplotlib.pyplot as plt
def plot(num_points,x,mean,variance,title):
    mean_predict=np.zeros(500)
    variance_predict=np.zeros(500)
    for i in range(len(x)):
        X=np.asarray([math.pow(x[i],k) for k in range(n)]).reshape(1, -1)
        mean_predict[i]=(mean.T@X.T).item()
        variance_predict[i] = ((a) + X@variance@X.T).item()
        
    plt.plot(point_x[:num_points],point_y[:num_points],'bo')
    plt.plot(x,mean_predict,'k-')
    plt.plot(x,mean_predict+variance_predict,'r-')
    plt.plot(x,mean_predict-variance_predict,'r-')
    plt.xlim(-2,2)
    plt.ylim(-15,25)
    plt.title(title)
    plt.show()

# %%
x=np.linspace(-2,2,500)
plot(10,x,mean_list[0],variance_list[0],'After 10 incomes')
plot(50,x,mean_list[1],variance_list[1],'After 50 incomes')
plot(NUM,x,mean_list[2],variance_list[2],'Predict result (1000 incomes)')
plot(0,x,w,np.zeros((n,n)),'Ground truth')
